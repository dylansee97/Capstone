# %%
import pandas as pd
df = pd.read_excel("NUS sample names_V2.xlsx", engine="openpyxl")

# %%
df.head(50)
# Out:
#                Name to be screened   Alias name        Date of birth  Gender  \
# 0                   Chia Teck Leng          NaN                 1960    Male
# 1                   Teck Leng Chia          NaN                 1960    Male
# 2                    Chia Tek Leng          NaN                 1960    Male
# 3                   Teo Cheng Kiat          NaN                  NaN    Male
# 4                   Cheng Kiat Teo          NaN                  NaN    Male
# 5                   Teo Cheng Keat          NaN                  NaN    Male
# 6                    Teo Chen Kiat          NaN                  NaN    Male
# 7                   Chong Hock Yen          NaN                 1960    Male
# 8                   Hock Yen Chong          NaN                 1960    Male
# 9                   Chong Hock Yan          NaN                 1960    Male
# 10                    Lim Oon Kuin          NaN                 1943    Male
# ...

# %%
# df2 = df[['Type of variation (if any)'] == 'Spelling/Phonetic ']
df.loc[df['Type of variation (if any)']=='Spelling/Phonetic']
# Out:
#       Name to be screened Alias name        Date of birth  Gender  \
# 2           Chia Tek Leng        NaN                 1960    Male
# 5          Teo Cheng Keat        NaN                  NaN    Male
# 9          Chong Hock Yan        NaN                 1960    Male
# 17            Lage Vivien        NaN                 1997  Female
# 24   Noordin Muhammad Top        NaN  1968-08-11 00:00:00    Male
# 30       Jan Sturzenegger        NaN                  NaN    Male
# 106   Rodrygo Duterte Roa        NaN                 1945    Male
# 114   Ameen Imam Boratong        NaN                    -    Male
# 125           Hose Calida        NaN                 1950    Male
# 135          Erwin Tulpho        NaN                  NaN    Male
# 153         Alan Burisima        NaN                 1959    Male
# 174          Park Chun il        NaN                 1954       -
#
#      Nationality Type of variation (if any)           Actual name
# ...

# %%
df.loc[df['Type of variation (if any)']=='Short/long form']
# Out:
#                Name to be screened Alias name Date of birth Gender  \
# 28  Mohammad Firdaus Kamal Intdzam        NaN          1987   Male
# 31                Jen Sturzenegger        NaN           NaN   Male
# 40              Bern Kan Cheok Yin        简作英           NaN   Male
#
#    Nationality Type of variation (if any)                 Actual name
# 28    Malaysia            Short/long form  Mohd Firdaus Kamal Intdzam
# 31      Sweden            Short/long form            Jen Sturzenegger
# 40   Singapore            Short/long form       Bernard Kan Cheok Yin
