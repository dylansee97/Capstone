# %%
import jellyfish
from fuzzywuzzy import fuzz
import pandas as pd
import numpy as np
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import requests
from newspaper import Article
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
import dateutil.parser as parser
from geopy.geocoders import Nominatim
import pycountry
import time
from datetime import date
from dateutil.relativedelta import relativedelta
import pinyin

nlp = en_core_web_sm.load()
nltk.download('vader_lexicon')

df = pd.read_excel("NUS sample names_V2.xlsx", engine="openpyxl")
df = df.where(pd.notnull(df), None)
# Out:
# C:\Users\USER\Anaconda\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Name to be screened must be in English
# Alias names can only handle Chinese characters , else return None
def preprocess_df_to_dict(df):
    def get_year(date):
        try:
            parser_obj = parser.parse(str(date))
            return parser_obj.year
        except:
            return None

    def get_month(date):
        if len(str(date))>4:
            try:
                return parser.parse(str(date)).month
            except:
                return None
        else:
            return None
            
    def get_day(date):
        if len(str(date))>4:
            try:
                return parser.parse(str(date)).day
            except:
                return None
        else:
            return None
    
    def isEnglish(s):
        try:
            s.encode(encoding='utf-8').decode('ascii')
        except UnicodeDecodeError:
            return False
        else:
            return True    
    
    df_dict_list = df.to_dict('records')
    cleaned_dict_list = []
    for record in df_dict_list:
        
        alias = record['Alias name']
        if alias is not None:
            alias_is_english = isEnglish(alias)
            if alias_is_english is False:
                try:
                    alias = pinyin.get(alias, format='strip', delimiter=' ')
                except:
                    alias = None
        current_record = {
            'name': record['Name to be screened'],
            'alias' : alias,
            'year_of_birth': get_year(record['Date of birth']),
            'month_of_birth': get_month(record['Date of birth']),
            'day_of_birth': get_day(record['Date of birth']),
            'gender': record['Gender'],
            'nationality': record['Nationality'],
            ### delete these later on, for testing only###
            'type_of_error': record['Type of variation (if any)'],
            'actual_name': record['Actual name'],
        }
        cleaned_dict_list.append(current_record)
    return cleaned_dict_list

# %%
df_dict = preprocess_df_to_dict(df)
test_record_1 = df_dict[0]
test_record_18 = df_dict[15]
print(test_record_18)
# Out:
# {'name': 'Lange Vivian', 'alias': None, 'year_of_birth': 1997, 'month_of_birth': None, 'day_of_birth': None, 'gender': 'Female', 'nationality': 'Singapore', 'type_of_error': '-', 'actual_name': 'Lange Vivian'}

# %% [markdown]
# # Name Matching

# %%
def ER_name_matching(name1, name2):
    def split_name_list(name):
        name = name.lower()
        output = name.split(" ")
        return output

    def preprocess_name(names_dict, word):
        for key, value in names_dict.items():
            if word in value:
                return key
        else:
            return word

    def stitch_name(list1):
        output = ''
        for x in range(len(list1)):
            if x==0:
                output += list1[x]
            else:
                output += ' ' + list1[x]
        return output

    def phonetic_comparison(list1, list2):
        meta_list1 = []
        meta_list2 = []
        nysiis_list1 = []
        nysiis_list2 = []
        for name_1 in list1:
            meta_list1.append(jellyfish.metaphone(name_1))
            nysiis_list1.append(jellyfish.nysiis(name_1))
        for name_2 in list2:
            meta_list2.append(jellyfish.metaphone(name_2))
            nysiis_list2.append(jellyfish.nysiis(name_2))
        if (set(meta_list1) == set(meta_list2)) or (set(nysiis_list1) == set(nysiis_list2)):
            return True
        else:
            return False
    
    def excel_to_dict(excel_file):
        excel_df = pd.read_excel(excel_file)
        excel_df.value.apply(str)
        before_transformation = dict(zip(excel_df.key, excel_df.value))
        dictionary = {key: [val for val in value.split(',')] for key, value in before_transformation.items()}
        return dictionary
            
    names_dict = excel_to_dict('names_dict.xlsx') 
    
    # START #
    ### Change this if needed ###
    threshold = 89
    #############################
    
    split_list_1 = split_name_list(name1)
    split_list_2 = split_name_list(name2) 
 
    
    for i in range(len(split_list_1)):
        split_list_1[i] = preprocess_name(names_dict, split_list_1[i])        
    for i in range(len(split_list_2)):
        split_list_2[i] = preprocess_name(names_dict, split_list_2[i])
    
    stitched_name1 = stitch_name(split_list_1)
    stitched_name2 = stitch_name(split_list_2)
    
    # 1st layer of testing: Token Sort Ratio with threshold
    score1 = fuzz.token_sort_ratio(stitched_name1, stitched_name2)
    if score1 >= threshold:
        # score_list.append(score1)
        return score1
        # do something
# 4) 2nd layer of testing - Metaphone and NYSIIS phonetic encoding - DONE
    else: 
        matched_phonetic = phonetic_comparison(split_list_1, split_list_2)
        if matched_phonetic:
            return threshold # assumption that phonetic match will give threshold score
        else: 
            return None
    
    try:
        return score1
    except:
        pass

# %% [markdown]
# # Nationality Matching

# %%
from geopy.exc import GeocoderServiceError

# hlpr func: get country by cities, states name
def get_country(gpe):
    geolocator = Nominatim(user_agent = "geoapiExercises")
    location = geolocator.geocode(gpe)
    if location:
        loc_lst = location.address.split(',')
        return loc_lst[-1]
    return None

# hlpr func: return a list of countries names
def countries():
    return list(map(lambda x: x.name, list(pycountry.countries)))

# hlpr func: return True if name countains country name
def contain_country(word, ctry_lst):
    for ctry in ctry_lst:
        if ctry.lower() in word.lower():
            return True
    return False

# hlpr func: extract entities with tag 'GPE', 'ORG', 'NORP'
def search_target_ent(tags):
    country_lst = countries()
    tag_lst = []
    for i in range(len(tags)):
        if tags[i][1] == 'GPE' or tags[i][1] == 'ORG' or tags[i][1] == 'NORP':
            if contain_country(tags[i][0], country_lst):
                tag_lst.append(tags[i])
    return tag_lst

# hlpr func: return the odd of the person's nationality in the article is nat
def calc_odd_nationality(nat,lst):
    try:
        result = []
        for tag in lst:
            if tag[0] is not None and nat is not None:
                if nat.lower() in tag[0].lower():
                    result.append(tag)
                    continue
            try:
                if tag[1] == 'GPE' and (get_country(tag[0]) is not None and nat is not None):
                    if get_country(tag[0]).lower() == nat.lower():
                        result.append(tag)
            except GeocoderServiceError as e:
                pass
        prob = 1 if ((len(lst) - len(result)) == 0 and len(result) > 0) else (len(result) / (len(lst) - len(result)))
        prob = 1 if prob > 1 else prob
        return prob
    except TypeError as e:
        pass

# hlpr func: return True if name fuzzy matching score > 80
def is_target(name, article_name):
    return fuzz.partial_ratio(name, article_name) > 80

# the main function for nationality matching
# return odd if target tags found else return -1
def nationality_matching(tags, nationality, person):
    result = []
    try:
        for i in range(len(tags)):
            #if second item is a name
            if tags[i][1] == 'PERSON':
                
                # check if is target
                if is_target(person, tags[i][0]):
                    search = search_target_ent(tags)
                
                    if len(search) != 0:
                        return calc_odd_nationality(nationality, search)
        return -1
    except IndexError as e:
        pass

# hlpr func: parse text to tags
def parse(text):
        #try:     
        doc = nlp(text)
        tags = [[X.text, X.label_] for X in doc.ents]
        labels = [x.label_ for x in doc.ents]
        items = [x.text for x in doc.ents]

        return tags

# %% [markdown]
# # Gender Matching

# %%
# hlpr func: return True if token is a name and subject
def is_name_subj(token):
    return token.dep_ =='nsubj' and token.pos_ == 'PROPN'

def is_part_of_name(token):
    return (token.dep_ =='nsubj' or token.dep_ =='compound') \
        and token.pos_ == 'PROPN'

# hlpr func: return True if the token is a determiner: his, her, hers
def is_det(token):
    return token.pos_ == 'DET' and (token.dep_ == 'poss' or token.dep_ == 'attr')

# hlpr func: return True if the token is a pronoun: he, she, herself, himself
def is_pron(token):
    return token.pos_ == 'PRON' and \
        (token.dep_ == 'nsubj' or token.dep_ == 'nsubjpass' or token.dep_ == 'pobj' or token.dep_ == 'dobj')

# hlpr func: return the probability of the gender in article to the true gender
def calc_prob_gender(pron_lst, gender):
    male_pron = ['he', 'his', 'himself', 'him']
    female_pron = ['she', 'her', 'herself', 'hers']
    n_target = 0
    gdr_pron = []
    
    if gender.lower() == 'male':
        gdr_pron = male_pron
    else:
        gdr_pron = female_pron
        
    for pron in pron_lst:
        if pron in gdr_pron:
            n_target += 1
    return n_target / len(pron_lst) if len(pron_lst) else 0

# the main function in gender matching
def gender_matching(text, gender, name):
    try:
        pron_lst = ['he', 'his', 'himself', 'him', 'she', 'her', 'herself', 'hers']
        name_str = ''
        target_name = name.replace(" ", "")
        target_found = False
        res_lst = []
        
        # text tagging
        doc = nlp(text)
        
        i = 0
        while i < len(doc):
            # search for target name of subject form
            if is_name_subj(doc[i]):
                end_name = i
                start_name = i
                while is_part_of_name(doc[start_name]):
                    start_name -= 1
                start_name += 1
                while start_name <= end_name:
                    name_str += doc[start_name].text
                    start_name += 1
                i += 1
            if is_target(name_str, target_name):
                target_found = True
            else:
                name_str = ''
                target_found = False
            
            # if target name is found, search for pronouns, break if another name is found
            while target_found:
                if is_name_subj(doc[i]):
                    target_found = False
                    name_str = ''
                    break
                if is_det(doc[i]) or is_pron(doc[i]):
                    if (doc[i].text).lower() in pron_lst:
                        res_lst.append((doc[i].text).lower())
                        break
                i += 1
            if is_name_subj(doc[i]):
                continue
            i += 1    
    except IndexError as e:
        pass
    return calc_prob_gender(res_lst, gender)

# %% [markdown]
# # Age Matching

# %%
useless_dates = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday','yesterday','today']

#index is index of person
def forward_searcher(index,tags):
    for i in range(index,len(tags)):
        if tags[i][1] == 'DATE' and tags[i][0] not in useless_dates:
            return tags[i]
    return [None,None]

def backward_searcher(index,tags):
    i = index
    while i >= 0:
        if tags[i][1] == 'DATE' and tags[i][0] not in useless_dates:
            return tags[i]
        else:
            i -=1

def detect_age(age,lst):
    try:
        if lst[1] is not None and lst[2] is not None:
            date1 = lst[1][0]
            date2 = lst[2][0]
            if (str(age) in date1) or (str(age) in date2):
                return True
        else:

            if lst[1] == None:
                if str(age) in lst[2][0]:
                    return True

            if lst[2] == None:
                if str(age) in lst[1][0]:
                    return True
    except TypeError as e:
        pass
    
    
def confirm_age(lst,age,threshold):
    iterating_lst = []
    plus = 1
    minus = -1
    for i in range(threshold):
        iterating_lst.append(age+plus)
        plus += 1
    for i in range(threshold):
        iterating_lst.append(age+minus)
        minus -=1 
    iterating_lst.append(age)
    
    for j in iterating_lst:
        if str(j) in lst[1][0]:
            return 1
    return 0

def age_matching(name_dict,tags,age):
    '''
    tags: parse(text)
    age: desired age to check
    '''
    for tag in tags:
        #if tag[1] == 'DATE':
            #print(tag)
        if str(age) in tag[0] or str(age+1) in tag[0] or str(age-1) in tag[0]:
            return 1
    result = []
    try:
        for i in range(len(tags)):
            #if second item is a name

            
            if tags[i][1] == 'PERSON':
                if tags[i][0] in name_dict:

                    forward_age = forward_searcher(i,tags)
                    backwards_age = backward_searcher(i,tags)
                    new_list = [tags[i],forward_age,backwards_age]
                    #new_list = [tags[i-1],tags[i],tags[i+1]]
                    #print(new_list)

                    if detect_age(age,new_list) and tags[i][0] in name_list:

                        #print(new_list)
                        #result += new_list

                        if str(age) in new_list[1][0]:
                            #print('****************')
                            #print([tags[i], new_list[1]])
                            return(confirm_age([tags[i],new_list[1]],age,3))


                        elif str(age) in new_list[2][0]:
                            #print('****************')
                            #print([tags[i],new_list[2]])
                            return(confirm_age([tags[i],new_list[2]],age,3))
                        
        return 0
    except IndexError as e:
        pass

# %% [markdown]
# # Entity recognition scoring for each_article

# %%
def entity_recognition_scoring_each_article(input_info, text, names_list):
    output = []
    input_name = input_info['name']


    article_names_list = names_list.most_common() 
    matched = False

    for each_name, each_count in article_names_list: ## as of now checking all names within the article, should we limit to e.g. top 3/5?
        if len(each_name.split()) == 1 and each_name in input_name:
            score = 100 ## if surname matches, default match score 100 
        else: 
            try: 
                score = ER_name_matching(input_name, each_name)
            except ValueError as e:
                pass
        if score is not None:
            matched = True
        if matched:
            break
    conf_score = 0
    if matched:
        name_score = score
        nationality_score = nationality_matching(parse(text), input_info['nationality'], input_info['name'])
        gender_score = gender_matching(text, input_info['gender'], input_info['name'])
        age_score = age_matching(names_list,parse(text),input_info['year_of_birth'])
            
        conf_score = (0.9071/100 * name_score) + (0.049973 * nationality_score) + (0.030293 * gender_score) + (0.012634 * age_score) 
    return conf_score

# %% [markdown]
# # Web Scraper

# %%
# Main Function
def search_articles_on_individual(individual_dict, no_of_articles=30):
    def generate_link(person_dict, attributes_used = ['name'], keywords=['crimes', 'sentenced']):
        link_start = "https://www.google.com/search?q="
        link_end = "&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2" 
        link_query = ""

        for attributes in attributes_used:
            temp_attr = person_dict[attributes]
            if temp_attr is not None:
                temp_attr = str(temp_attr)
                link_query += temp_attr.replace(' ', '+') + '+'       
                
        links = []
        for keyword in keywords:
            temp_search_link = link_start + link_query + keyword + link_end + "&num=" + str(no_of_articles)
            links.append(temp_search_link)
        return links
    
    def article_extraction(link):
        article = Article(link)
        article.download()
        try:
            article.parse()
        except:
            pass
        return article.text

    def parse(text):
        #try:     
        doc = nlp(text)
        tags = [[X.text, X.label_] for X in doc.ents]
        labels = [x.label_ for x in doc.ents]
        items = [x.text for x in doc.ents]

        return tags

    def find_names(tags):
        names = []
        for tag in tags:
            if tag[1] == 'PERSON':
                names.append(tag[0])
        return names

    def sentiment_analysis(text):
        return vader.polarity_scores(text)
    
    def time_to_months(time):
        if 'weeks' in time:
            return 0
        else:
            return int(time.split(' month')[0])

    search_links = generate_link(individual_dict)
    
    unique_links_checker = []
    
    output = []
    for x in search_links:
        print("SEARCHING THIS", x)
        req = Request(x, headers = {'User-Agent': 'Mozilla/5.0'})

        webpage = urlopen(req).read()

        with requests.Session() as c:
            soup = BeautifulSoup(webpage, 'html5lib')
            #print(soup)
            for item in soup.find_all('div', attrs = {'class': "ZINbbc xpd O9g5cc uUPGi"}):
                current_dict = {}
                raw_link = (item.find('a', href = True)['href'])
                try:
                    link = (raw_link.split("/url?q=")[1]).split('&sa=U&')[0]
                except IndexError as e1:
                    continue
                if link not in unique_links_checker and item:
                    unique_links_checker.append(link)
                    title = item.find('div',attrs = {'class': 'BNeawe vvjwJb AP7Wnd'})
                    if title == None:
                        continue
                    title = title.get_text()
                    description  = (item.find('div',attrs = {'class': 'BNeawe s3v9rd AP7Wnd'}).get_text())
                    time = description.split(" · ")[0]
                    #print(description)
                    descript = description.split(" · ")[1]
                    
                    # create names_list
                    parsed_description = parse(description)
                    names_in_description = find_names(parsed_description) 
                    parsed_text = parse(article_extraction(link))
                    names_in_text = find_names(parsed_text)
                    names_list = Counter(names_in_description + names_in_text)
                    
                    # extract text
                    text = article_extraction(link)

                    # compute confidence score before accepting the article
                    conf_score = entity_recognition_scoring_each_article(individual_dict, text, names_list)
                    if conf_score < 0.95:
                        continue
                    current_dict['title'] = title
                    current_dict['time'] = time
                    try:
                        current_dict['year_of_birth'] = (date.today() - relativedelta(months = time_to_months(time))).year - individual_dict['year_of_birth']
                    except TypeError as e1:
                        current_dict['year_of_birth'] = 0
                    except ValueError as e2:
                        current_dict['year_of_birth'] = 0
                    current_dict['description'] = descript
                    current_dict['link'] = link
                    current_dict['text'] = text
                    current_dict['sentiment?'] = sentiment_analysis(article_extraction(link))
                    current_dict['names_list'] = names_list
                    current_dict['confidence_score'] = conf_score
                    
                    output.append(current_dict)
                else:
                    pass
    return output

new_words = {
    'crushes': 10,
    'beats': 5,
    'misses': -5,
    'trouble': -10,
    'falls': -100,
    'bankrupt': -100,
    'fraud': -100,
    'crime': -100,
    'prison': -100,
    'embezzlement': -100,
    'money_trail':-100,
    'jail': -100,
    'sentenced':-100,
    'forfeiture': -100,
    'ill-gotten gain':-100,
    'laundering':-100
}

vader = SentimentIntensityAnalyzer()

vader.lexicon.update(new_words)

# %% [markdown]
# # Old Entity scoring function

# %%
def entity_recognition_scoring(input_info, list_of_article_dicts):
    output = []
    input_name = input_info['name']

    for article in list_of_article_dicts:
        article_names_list = article['names_list'].most_common() 
        matched = False
        
        for each_name, each_count in article_names_list: ## as of now checking all names within the article, should we limit to e.g. top 3/5?
            if len(each_name.split()) == 1 and each_name in input_name:
                score = 100 ## if surname matches, default match score 100 
            else: 
                try: 
                    score = ER_name_matching(input_name, each_name)
                except ValueError as e:
                    pass
            if score is not None:
                matched = True
            if matched:
                break
     
        if matched:
            # keep article
            article['name_matching_score'] = score

            # nationality matching score
            article ['nationality_matching_score'] = nationality_matching(parse(article['text']), input_info['nationality'], input_info['name'])

            # gender matching score
            article ['gender_matching_score'] =gender_matching(article['text'], input_info['gender'], input_info['name'])
            
            article['age_matching_score'] = age_matching(article['names_list'],parse(article['text']),article['year_of_birth'])
            #print(article['year_of_birth'])

            output.append(article)
    return output

# %%
test_query = search_articles_on_individual(test_record_18, 10)
pd.DataFrame(test_query)
# Out:
# SEARCHING THIS https://www.google.com/search?q=Lange+Vivian+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=10
# SEARCHING THIS https://www.google.com/search?q=Lange+Vivian+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=10
#                                                title           time  \
# 0  Woman first to be charged under new anti-money...  15 months ago
#
#    year_of_birth                                        description  \
# 0             23  Lange Vivian was on Wednesday (June 24) charge...
#
#                                                 link  \
# 0  https://www.straitstimes.com/singapore/courts-...
#
#                                                 text  \
# 0  SINGAPORE - A 23-year-old woman is the first p...
#
#                                           sentiment?  \
# 0  {'neg': 0.439, 'neu': 0.553, 'pos': 0.008, 'co...
#
#                                           names_list  confidence_score
# 0  {'Lange Vivian': 1, 'Lange': 3, 'Toa Payoh and...          0.957073

# %%
test_record_18
# Out:
# {'name': 'Lange Vivian',
#  'alias': None,
#  'year_of_birth': 1997,
#  'month_of_birth': None,
#  'day_of_birth': None,
#  'gender': 'Female',
#  'nationality': 'Singapore',
#  'type_of_error': '-',
#  'actual_name': 'Lange Vivian'}

# %%
name_matched = entity_recognition_scoring(test_record_18, test_query)
pd.DataFrame(name_matched)
# Out:
#                                                title           time  \
# 0  Woman first to be charged under new anti-money...  15 months ago
#
#    year_of_birth                                        description  \
# 0             23  Lange Vivian was on Wednesday (June 24) charge...
#
#                                                 link  \
# 0  https://www.straitstimes.com/singapore/courts-...
#
#                                                 text  \
# 0  SINGAPORE - A 23-year-old woman is the first p...
#
#                                           sentiment?  \
# 0  {'neg': 0.439, 'neu': 0.553, 'pos': 0.008, 'co...
#
#                                           names_list  confidence_score  \
# 0  {'Lange Vivian': 1, 'Lange': 3, 'Toa Payoh and...          0.957073
#
#    name_matching_score  nationality_matching_score  gender_matching_score  \
# 0                  100                           1                      0
#
#    age_matching_score
# 0                   1

# %%
name_matched
# Out:
# [{'title': 'Woman first to be charged under new anti-money laundering law',
#   'time': '15 months ago',
#   'year_of_birth': 23,
#   'description': 'Lange Vivian was on Wednesday (June 24) charged with one count of ... of crime from victims of online scams," a police spokesman said.',
#   'link': 'https://www.straitstimes.com/singapore/courts-crime/woman-first-to-be-charged-under-new-anti-money-laundering-law',
#   'text': 'SINGAPORE - A 23-year-old woman is the first person to be charged under a new law that fights money laundering and terrorism financing.\n\nLange Vivian was on Wednesday (June 24) charged with one count of providing payment services without a licence under the Payment Services Act.\n\nThe law, which also aims to strengthen consumer protection in the use of e-payments, was introduced on Jan 28.\n\nThe Singaporean allegedly provided a digital payment token service between Feb 27 and 28 this year.\n\nIn a statement on Tuesday, the police said that she allegedly received at least 13 fraudulent fund transfers this way.\n\nIn total, she is accused of receiving around $3,000 in her bank account.\n\nLange is said to have then used the proceeds to buy Bitcoin.\n\n"These transactions were done on the instruction of an unknown person in return for a commission.\n\n"The monies deposited in her bank account turned out to be proceeds of crime from victims of online scams," a police spokesman said.\n\nThe police did not reveal details of these scams.\n\nLange had earlier been charged with 10 counts of acting on behalf of a loan shark known only as "Boss".\n\nOn May 13 last year, Lange and another man are said to have gone to a Housing Board flat in Hougang to commit acts such as defacing the front door with paint.\n\nThey are also accused of targeting other flats at places such as Toa Payoh and Tampines. This went on until May 21 last year.\n\nLange\'s bail was set at $15,000 and her pre-trial conference will be held on July 22.\n\nIf convicted of the offence under the Payment Services Act, she can be jailed for up to three years and fined up to $125,000.\n\nFor each charge of acting on behalf of a loan shark, an offender can be jailed for up to five years, fined a maximum $50,000 and receive up to six strokes of the cane.\n\nLange cannot be caned, as she is a woman.',
#   'sentiment?': {'neg': 0.439,
#    'neu': 0.553,
#    'pos': 0.008,
#    'compound': -0.9998},
#   'names_list': Counter({'Lange Vivian': 1,
#            'Lange': 3,
#            'Toa Payoh and Tampines': 1}),
#   'confidence_score': 0.9570730000000002,
#   'name_matching_score': 100,
#   'nationality_matching_score': 1,
#   'gender_matching_score': 0,
#   'age_matching_score': 1}]

# %%
df_dict
# Out:
# [{'name': 'Chia Teck Leng',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Chia Teck Leng'},
#  {'name': 'Teck Leng Chia',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Chia Teck Leng'},
#  {'name': 'Chia Tek Leng',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Chia Teck Leng'},
#  {'name': 'Teo Cheng Kiat',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Teo Cheng Kiat'},
#  {'name': 'Cheng Kiat Teo',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Teo Cheng Kiat'},
#  {'name': 'Teo Cheng Keat',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Teo Cheng Kiat'},
#  {'name': 'Teo Chen Kiat',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Typo',
#   'actual_name': 'Teo Cheng Kiat'},
#  {'name': 'Chong Hock Yen',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Chong Hock Yen'},
#  {'name': 'Hock Yen Chong',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Chong Hock Yen'},
#  {'name': 'Chong Hock Yan',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Chong Hock Yen'},
#  {'name': 'Lim Oon Kuin',
#   'alias': None,
#   'year_of_birth': 1943,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Lim Oon Kuin'},
#  {'name': 'Oon Kuin Lim',
#   'alias': None,
#   'year_of_birth': 1943,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Lim Oon Kuin'},
#  {'name': 'Lim Oon Quin',
#   'alias': None,
#   'year_of_birth': 1943,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Phonetic variations',
#   'actual_name': 'Lim Oon Kuin'},
#  {'name': 'Tan Wee Beng',
#   'alias': None,
#   'year_of_birth': 1977,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Tan Wee Beng'},
#  {'name': 'Tan Wee Bing',
#   'alias': None,
#   'year_of_birth': 1977,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Typo',
#   'actual_name': 'Tan Wee Beng'},
#  {'name': 'Lange Vivian',
#   'alias': None,
#   'year_of_birth': 1997,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Female',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Lange Vivian'},
#  {'name': 'Lage Vivian',
#   'alias': None,
#   'year_of_birth': 1997,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Female',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Lange Vivian'},
#  {'name': 'Lage Vivien',
#   'alias': None,
#   'year_of_birth': 1997,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Female',
#   'nationality': 'Singapore',
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Lange Vivian'},
#  {'name': 'Laeg Vivian',
#   'alias': None,
#   'year_of_birth': 1997,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Female',
#   'nationality': 'Singapore',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Lange Vivian'},
#  {'name': 'Mas Selamat Kastari',
#   'alias': None,
#   'year_of_birth': 1961,
#   'month_of_birth': 1,
#   'day_of_birth': 23,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Mas Selamat Kastari'},
#  {'name': 'Mas Salamat Kestari',
#   'alias': None,
#   'year_of_birth': 1961,
#   'month_of_birth': 1,
#   'day_of_birth': 23,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Phonetic variations',
#   'actual_name': 'Mas Selamat Kastari'},
#  {'name': 'Selamat Mas Kastari',
#   'alias': None,
#   'year_of_birth': 1961,
#   'month_of_birth': 1,
#   'day_of_birth': 23,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'name order variation',
#   'actual_name': 'Mas Selamat Kastari'},
#  {'name': 'Msa Salemat Kastari',
#   'alias': None,
#   'year_of_birth': 1961,
#   'month_of_birth': 1,
#   'day_of_birth': 23,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Mas Selamat Kastari'},
#  {'name': 'Noordin Mohammad Top',
#   'alias': None,
#   'year_of_birth': 1968,
#   'month_of_birth': 8,
#   'day_of_birth': 11,
#   'gender': 'Male',
#   'nationality': 'Malaysia',
#   'type_of_error': '-',
#   'actual_name': 'Noordin Mohammad Top'},
#  {'name': 'Noordin Muhammad Top',
#   'alias': None,
#   'year_of_birth': 1968,
#   'month_of_birth': 8,
#   'day_of_birth': 11,
#   'gender': 'Male',
#   'nationality': 'Malaysia',
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Noordin Mohammad Top'},
#  {'name': 'Norodni Mohamamd Tpo',
#   'alias': None,
#   'year_of_birth': 1968,
#   'month_of_birth': 8,
#   'day_of_birth': 11,
#   'gender': 'Male',
#   'nationality': 'Malaysia',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Noordin Mohammad Top'},
#  {'name': 'Mohd Firdaus Kamal Intdzam',
#   'alias': None,
#   'year_of_birth': 1987,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Malaysia',
#   'type_of_error': '-',
#   'actual_name': 'Mohd Firdaus Kamal Intdzam'},
#  {'name': 'Mohd Kamal Firdaus Intdsam',
#   'alias': None,
#   'year_of_birth': 1987,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Malaysia',
#   'type_of_error': 'name order variation, Spelling/Phonetic',
#   'actual_name': 'Mohd Firdaus Kamal Intdzam'},
#  {'name': 'Mohammad Firdaus Kamal Intdzam',
#   'alias': None,
#   'year_of_birth': 1987,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Malaysia',
#   'type_of_error': 'Short/long form',
#   'actual_name': 'Mohd Firdaus Kamal Intdzam'},
#  {'name': 'Jens Fred Sturzenegger',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Sweden',
#   'type_of_error': '-',
#   'actual_name': 'Jens Fred Sturzenegger'},
#  {'name': 'Jan Sturzenegger',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Sweden',
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Jen Sturzenegger'},
#  {'name': 'Jen Sturzenegger',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Sweden',
#   'type_of_error': 'Short/long form',
#   'actual_name': 'Jen Sturzenegger'},
#  {'name': 'Bidzina Ivanishvili',
#   'alias': None,
#   'year_of_birth': 1956,
#   'month_of_birth': 2,
#   'day_of_birth': 18,
#   'gender': 'Male',
#   'nationality': 'Georgia',
#   'type_of_error': '-',
#   'actual_name': 'Bidzina Ivanishvili'},
#  {'name': 'Ivanishvili Bidzina',
#   'alias': None,
#   'year_of_birth': 1956,
#   'month_of_birth': 2,
#   'day_of_birth': 18,
#   'gender': 'Male',
#   'nationality': 'Georgia',
#   'type_of_error': 'name order variation',
#   'actual_name': 'Bidzina Ivanishvili'},
#  {'name': 'Bdizian Ianvishvlii',
#   'alias': None,
#   'year_of_birth': 1956,
#   'month_of_birth': 2,
#   'day_of_birth': 18,
#   'gender': 'Male',
#   'nationality': 'Georgia',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Bidzina Ivanishvili'},
#  {'name': 'Bedzina Ivenishvili',
#   'alias': None,
#   'year_of_birth': 1956,
#   'month_of_birth': 2,
#   'day_of_birth': 18,
#   'gender': 'Male',
#   'nationality': 'Georgia',
#   'type_of_error': 'Typo',
#   'actual_name': 'Bidzina Ivanishvili'},
#  {'name': 'Bernard Kan Cheok Yin',
#   'alias': 'jian zuo ying',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Bernard Kan Cheok Yin'},
#  {'name': 'Gan Cheok Yin',
#   'alias': 'jian zuo ying',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Transcription',
#   'actual_name': 'Bernard Kan Cheok Yin'},
#  {'name': 'Kan Cheok Yin Benard',
#   'alias': 'jian zuo ying',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'name order variation, Typo',
#   'actual_name': 'Bernard Kan Cheok Yin'},
#  {'name': 'Brenard Kan Choek Yin',
#   'alias': 'jian zuo ying',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Bernard Kan Cheok Yin'},
#  {'name': 'Bern Kan Cheok Yin',
#   'alias': 'jian zuo ying',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Short/long form',
#   'actual_name': 'Bernard Kan Cheok Yin'},
#  {'name': 'Ng Yu Zhi',
#   'alias': None,
#   'year_of_birth': 1987,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Ng Yu Zhi'},
#  {'name': 'Ng Yu Zhe',
#   'alias': None,
#   'year_of_birth': 1987,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Typo',
#   'actual_name': 'Ng Yu Zhi'},
#  {'name': 'Ng Yu Zih',
#   'alias': None,
#   'year_of_birth': 1987,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Ng Yu Zhi'},
#  {'name': 'LAI, Yong Chian',
#   'alias': 'Leonard LAI',
#   'year_of_birth': 1958,
#   'month_of_birth': 6,
#   'day_of_birth': 16,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'LAI, Yong Chian'},
#  {'name': 'LAI, Yong Qian',
#   'alias': 'Leonard LAI',
#   'year_of_birth': 1958,
#   'month_of_birth': 6,
#   'day_of_birth': 16,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Typo',
#   'actual_name': 'LAI, Yong Chian'},
#  {'name': 'chian lai yong',
#   'alias': None,
#   'year_of_birth': 1958,
#   'month_of_birth': 6,
#   'day_of_birth': 16,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'LAI, Yong Chian'},
#  {'name': 'Ahmed Faysal',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Bangladesh',
#   'type_of_error': '-',
#   'actual_name': 'Ahmed Faysal'},
#  {'name': 'Ahmed Faisar',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Bangladesh',
#   'type_of_error': 'Typo',
#   'actual_name': 'Ahmed Faysal'},
#  {'name': 'Ng Kheng Wah',
#   'alias': None,
#   'year_of_birth': 1962,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Ng Kheng Wah'},
#  {'name': 'Kheng Ng Wah',
#   'alias': None,
#   'year_of_birth': 1962,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Ng Kheng Wah'},
#  {'name': 'Ng King Wa',
#   'alias': None,
#   'year_of_birth': 1962,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Typo',
#   'actual_name': 'Ng Kheng Wah'},
#  {'name': 'Wang Zhiguo',
#   'alias': None,
#   'year_of_birth': 1963,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'China',
#   'type_of_error': '-',
#   'actual_name': 'Wang Zhiguo'},
#  {'name': 'Huang Zhiguo',
#   'alias': None,
#   'year_of_birth': 1963,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'China',
#   'type_of_error': 'Transcription',
#   'actual_name': 'Wang Zhiguo'},
#  {'name': 'Huaang Zhiguo',
#   'alias': None,
#   'year_of_birth': 1963,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'China',
#   'type_of_error': 'Phonetic variations',
#   'actual_name': 'Wang Zhiguo'},
#  {'name': 'Wnag Zihgou',
#   'alias': None,
#   'year_of_birth': 1963,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'China',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Wang Zhiguo'},
#  {'name': 'Tay Sheng Yang',
#   'alias': 'Allister Tay',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Tay Sheng Yang'},
#  {'name': 'Sheng Yang Tay',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Tay Sheng Yang'},
#  {'name': 'Tay Shen Yan',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Typo',
#   'actual_name': 'Tay Sheng Yang'},
#  {'name': 'Tay Sehng Ynag',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Tay Sheng Yang'},
#  {'name': 'SAHIN Huseyin',
#   'alias': None,
#   'year_of_birth': 1957,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'SAHIN Huseyin'},
#  {'name': 'SAHI Huseying',
#   'alias': None,
#   'year_of_birth': 1957,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'SAHIN Huseyin'},
#  {'name': 'ABDUL AL MAJID',
#   'alias': None,
#   'year_of_birth': 1955,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': '-',
#   'actual_name': 'ABDUL AL MAJID'},
#  {'name': 'Abdulalmajid',
#   'alias': None,
#   'year_of_birth': 1955,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': 'Transcription',
#   'actual_name': 'ABDUL AL MAJID'},
#  {'name': 'ARDHAN, Muhamad Ricky',
#   'alias': 'SYAH, Heris',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': '-',
#   'actual_name': 'ARDHAN, Muhamad Ricky'},
#  {'name': 'ARDHAN, Mohd Ricky',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': 'Short/Long Form, Phonetic',
#   'actual_name': 'ARDHAN, Muhamad Ricky'},
#  {'name': 'UMANGIS MIKE',
#   'alias': 'JAFAR, Anis Alawi',
#   'year_of_birth': 1966,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': '-',
#   'actual_name': 'UMANGIS MIKE'},
#  {'name': 'UMANGIS MICHAEL',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': 'Short/Long Form',
#   'actual_name': 'UMANGIS MIKE'},
#  {'name': 'TORIQUDDIN',
#   'alias': 'RUSDAN, Abu',
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'TORIQUDDIN'},
#  {'name': 'SYAH, Heris',
#   'alias': 'ABDUL RAHMAN,\nMuhammad Jibril',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': '-',
#   'actual_name': 'SYAH, Heris'},
#  {'name': 'Muhammad Bahrun Naim Anggih',
#   'alias': 'AISYAH, Abu',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': '-',
#   'actual_name': 'Muhammad Bahrun Naim Anggih'},
#  {'name': 'Rachmat Yasin',
#   'alias': None,
#   'year_of_birth': 1963,
#   'month_of_birth': 11,
#   'day_of_birth': 4,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': '-',
#   'actual_name': 'Rachmat Yasin'},
#  {'name': 'YAZID SUFAAT',
#   'alias': 'Yazud bin Sufaat',
#   'year_of_birth': 1964,
#   'month_of_birth': 1,
#   'day_of_birth': 20,
#   'gender': 'Male',
#   'nationality': 'Malaysia',
#   'type_of_error': '-',
#   'actual_name': 'YAZID SUFAAT'},
#  {'name': 'MUHAMMAD AL-INDUNISI, Abu',
#   'alias': 'SYAH, Bahrum',
#   'year_of_birth': 1984,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': '-',
#   'actual_name': 'MUHAMMAD AL-INDUNISI, Abu'},
#  {'name': 'MUHAMMADALINDUNISI',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': 'Short/Long Form, Phonetic',
#   'actual_name': 'MUHAMMAD AL-INDUNISI, Abu'},
#  {'name': 'PETER SONDAKH',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'PETER SONDAKH'},
#  {'name': 'PETER SONDAK',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'PETER SONDAKH'},
#  {'name': 'PETER SONJAK',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transcription',
#   'actual_name': 'PETER SONDAKH'},
#  {'name': 'GARIBALDI THOHIR',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'GARIBALDI THOHIR'},
#  {'name': 'GARIBADI THOHI',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'GARIBALDI THOHIR'},
#  {'name': 'Mikael Kambuaya',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Mikael Kambuaya'},
#  {'name': 'Michael Kambuaya',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transcription',
#   'actual_name': 'Mikael Kambuaya'},
#  {'name': 'Mike Kambuaya',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Short/Long Form',
#   'actual_name': 'Mikael Kambuaya'},
#  {'name': 'Pinangki Sirna Malasari',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Female',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Pinangki Sirna Malasari'},
#  {'name': 'Djoko Tjandra',
#   'alias': 'Tjan Kok Hui',
#   'year_of_birth': 1951,
#   'month_of_birth': 8,
#   'day_of_birth': 27,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Djoko Tjandra'},
#  {'name': 'Joko Tjandra',
#   'alias': None,
#   'year_of_birth': 1951,
#   'month_of_birth': 8,
#   'day_of_birth': 27,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transcription',
#   'actual_name': 'Djoko Tjandra'},
#  {'name': 'Djoko Tanjdar',
#   'alias': None,
#   'year_of_birth': 1951,
#   'month_of_birth': 8,
#   'day_of_birth': 27,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Djoko Tjandra'},
#  {'name': 'Tubagus Chaeri Wardana',
#   'alias': 'Wawan',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Tubagus Chaeri Wardana'},
#  {'name': 'Budi Santoso',
#   'alias': None,
#   'year_of_birth': 1948,
#   'month_of_birth': 2,
#   'day_of_birth': 28,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Budi Santoso'},
#  {'name': 'Budy Santoso',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transcription',
#   'actual_name': 'Budi Santoso'},
#  {'name': 'Irzal Rinaldi Zailani',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Irzal Rinaldi Zailani'},
#  {'name': 'Irsal Rinaldi Sailani',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Phonetic variations',
#   'actual_name': 'Irzal Rinaldi Zailani'},
#  {'name': 'Risyanto Suanda',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Risyanto Suanda'},
#  {'name': 'Risayanto Suanda',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Risyanto Suanda'},
#  {'name': 'Rizyanto Suanda',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Phonetic variations',
#   'actual_name': 'Risyanto Suanda'},
#  {'name': 'Muhammad Romahurmuziy',
#   'alias': 'Romy',
#   'year_of_birth': 1974,
#   'month_of_birth': 9,
#   'day_of_birth': 10,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Muhammad Romahurmuziy'},
#  {'name': 'Mohamed Romy',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Short/Long Form',
#   'actual_name': 'Muhammad Romahurmuziy'},
#  {'name': 'SABRINA ABU',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'SABRINA ABU'},
#  {'name': 'SHABRINA, Abu',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Phonetic variations',
#   'actual_name': 'SABRINA ABU'},
#  {'name': 'ABDUL TAIB MAHMUD',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'ABDUL TAIB MAHMUD'},
#  {'name': 'ABDUL TIAB MAHMUD',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'ABDUL TAIB MAHMUD'},
#  {'name': 'Prasetyo Utomo',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Prasetyo Utomo'},
#  {'name': 'Utomo Prasetyo',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Prasetyo Utomo'},
#  {'name': 'Rodrigo Roa Duterte',
#   'alias': None,
#   'year_of_birth': 1945,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Philippines',
#   'type_of_error': '-',
#   'actual_name': 'Rodrigo Roa Duterte'},
#  {'name': 'Duterte Roa Rodrigo',
#   'alias': None,
#   'year_of_birth': 1945,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Philippines',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Rodrigo Roa Duterte'},
#  {'name': 'Rodrigo Roa',
#   'alias': None,
#   'year_of_birth': 1945,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Philippines',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Rodrigo Roa Duterte'},
#  {'name': 'Rodrygo Duterte Roa',
#   'alias': None,
#   'year_of_birth': 1945,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Philippines',
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Rodrigo Roa Duterte'},
#  {'name': 'Rodrgio Duteert Rao',
#   'alias': None,
#   'year_of_birth': 1945,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Philippines',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Rodrigo Roa Duterte'},
#  {'name': 'Rodrigol Roaa Dutertee',
#   'alias': None,
#   'year_of_birth': 1945,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Philippines',
#   'type_of_error': 'Typo',
#   'actual_name': 'Rodrigo Roa Duterte'},
#  {'name': 'Amin Imam Boratong',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Amin Imam Boratong'},
#  {'name': 'Amin Boratong',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Amin Imam Boratong'},
#  {'name': 'Amin Boratong Imam',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Amin Imam Boratong'},
#  {'name': 'Amin Boratngo Imam',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Amin Imam Boratong'},
#  {'name': 'Ami Imam Boratong',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Amin Imam Boratong'},
#  {'name': 'Ameen Imam Boratong',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Amin Imam Boratong'},
#  {'name': 'Roberto Salas Benedicto',
#   'alias': None,
#   'year_of_birth': 1917,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Roberto Salas Benedicto'},
#  {'name': 'Roberto Benedicto Salas',
#   'alias': None,
#   'year_of_birth': 1917,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Roberto Salas Benedicto'},
#  {'name': 'Roberot Salas Benedict',
#   'alias': None,
#   'year_of_birth': 1917,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Roberto Salas Benedicto'},
#  {'name': 'Robert Benedict Salas',
#   'alias': None,
#   'year_of_birth': 1917,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Roberto Salas Benedicto'},
#  {'name': 'Bob Benedict Salas',
#   'alias': None,
#   'year_of_birth': 1917,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Short/Long Form',
#   'actual_name': 'Roberto Salas Benedicto'},
#  {'name': 'Jose Calida',
#   'alias': None,
#   'year_of_birth': 1950,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Jose Calida'},
#  {'name': 'José Calida',
#   'alias': None,
#   'year_of_birth': 1950,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Diacritical mark/accent variations',
#   'actual_name': 'Jose Calida'},
#  {'name': 'Calida Jose',
#   'alias': None,
#   'year_of_birth': 1950,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Jose Calida'},
#  {'name': 'Jose Cailda',
#   'alias': None,
#   'year_of_birth': 1950,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Jose Calida'},
#  {'name': 'Jos Calida',
#   'alias': None,
#   'year_of_birth': 1950,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Jose Calida'},
#  {'name': 'Hose Calida',
#   'alias': None,
#   'year_of_birth': 1950,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Jose Calida'},
#  {'name': 'Antonio Floirendo, Sr.',
#   'alias': None,
#   'year_of_birth': 1915,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Antonio Floirendo, Sr.'},
#  {'name': 'Antonio Sr. Floirendo',
#   'alias': None,
#   'year_of_birth': 1915,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Antonio Floirendo, Sr.'},
#  {'name': 'Antiiono Sr. Floirendo',
#   'alias': None,
#   'year_of_birth': 1915,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Antonio Floirendo, Sr.'},
#  {'name': 'Antoni Floirendo, Sr.',
#   'alias': None,
#   'year_of_birth': 1915,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Antonio Floirendo, Sr.'},
#  {'name': 'Antonio Floirendo, Senior',
#   'alias': None,
#   'year_of_birth': 1915,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Short/Long Form',
#   'actual_name': 'Antonio Floirendo, Sr.'},
#  {'name': 'Erwin Tulfo',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Erwin Tulfo'},
#  {'name': 'Tulfo Erwin',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Erwin Tulfo'},
#  {'name': 'Eriwn Tulof',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Erwin Tulfo'},
#  {'name': 'Erwin Turlfur',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Erwin Tulfo'},
#  {'name': 'Erwin Tulpho',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Erwin Tulfo'},
#  {'name': 'Lucio Tan',
#   'alias': None,
#   'year_of_birth': 1934,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Lucio Tan'},
#  {'name': 'Tan Lucio',
#   'alias': None,
#   'year_of_birth': 1934,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Lucio Tan'},
#  {'name': 'Lucoi Tan',
#   'alias': None,
#   'year_of_birth': 1934,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Lucio Tan'},
#  {'name': 'Lucioooo Tam',
#   'alias': None,
#   'year_of_birth': 1934,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Lucio Tan'},
#  {'name': 'Lucius Tan',
#   'alias': None,
#   'year_of_birth': 1934,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Short/Long Form',
#   'actual_name': 'Lucio Tan'},
#  {'name': 'Hung Kin Sing Jimmy',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Hung Kin Sing Jimmy'},
#  {'name': 'Hung Jimmy',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Hung Kin Sing Jimmy'},
#  {'name': 'Jimmy Hung Kin Sing',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Hung Kin Sing Jimmy'},
#  {'name': 'Jimmy Kin Hung Sing',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Hung Kin Sing Jimmy'},
#  {'name': 'Hnug Kni Sing Jimmy',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Hung Kin Sing Jimmy'},
#  {'name': 'Hungg Kin Sim Jimmy',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Hung Kin Sing Jimmy'},
#  {'name': 'Hung Kin Sing Jim',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Short/Long Form',
#   'actual_name': 'Hung Kin Sing Jimmy'},
#  {'name': 'Hung Kin Sing James',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Short/Long Form',
#   'actual_name': 'Hung Kin Sing Jimmy'},
#  {'name': 'Alan Purisima',
#   'alias': None,
#   'year_of_birth': 1959,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Alan Purisima'},
#  {'name': 'Purisima Alan',
#   'alias': None,
#   'year_of_birth': 1959,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Alan Purisima'},
#  {'name': 'Aaln Purisima',
#   'alias': None,
#   'year_of_birth': 1959,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Alan Purisima'},
#  {'name': 'Aln Purisma',
#   'alias': None,
#   'year_of_birth': 1959,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Alan Purisima'},
#  {'name': 'Alan Burisima',
#   'alias': None,
#   'year_of_birth': 1959,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Alan Purisima'},
#  {'name': 'Chang Chang Ha',
#   'alias': None,
#   'year_of_birth': 1964,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Chang Chang Ha'},
#  {'name': 'Chang Ha Chang',
#   'alias': None,
#   'year_of_birth': 1964,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Chang Chang Ha'},
#  {'name': 'Chnga Cghna Ah',
#   'alias': None,
#   'year_of_birth': 1964,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Chang Chang Ha'},
#  {'name': 'Chang Chang Haaaaaa',
#   'alias': None,
#   'year_of_birth': 1964,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Chang Chang Ha'},
#  {'name': 'Jang Jang Ha',
#   'alias': None,
#   'year_of_birth': 1964,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Transcription',
#   'actual_name': 'Chang Chang Ha'},
#  {'name': 'Kim Song Chol',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': '-',
#   'actual_name': 'Kim Song Chol'},
#  {'name': 'Kim Chol Song',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Kim Song Chol'},
#  {'name': 'Kmi Snog Chol',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Kim Song Chol'},
#  {'name': 'Kimm Chol Songg',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Typo',
#   'actual_name': 'Kim Song Chol'},
#  {'name': 'Kim Sung Cheol',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Transcription',
#   'actual_name': 'Kim Song Chol'},
#  {'name': 'Kim Seong Chol',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': None,
#   'nationality': 'North Korea',
#   'type_of_error': 'Transcription',
#   'actual_name': 'Kim Song Chol'},
#  {'name': 'Cho Chun Ryong',
#   'alias': 'Jo, Chun Ryong',
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Cho Chun Ryong'},
#  {'name': 'Cho Ryong Chun',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Cho Chun Ryong'},
#  {'name': 'Coh Royng Chun',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Cho Chun Ryong'},
#  {'name': 'Choo Chung Ryoung',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Cho Chun Ryong'},
#  {'name': 'Jo Jun Yong',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Transcription',
#   'actual_name': 'Cho Chun Ryong'},
#  {'name': 'Pak Chun il',
#   'alias': None,
#   'year_of_birth': 1954,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': '-',
#   'actual_name': 'Pak Chun il'},
#  {'name': 'Pak il Chun',
#   'alias': None,
#   'year_of_birth': 1954,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Pak Chun il'},
#  {'name': 'Pak chun li',
#   'alias': None,
#   'year_of_birth': 1954,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Pak Chun il'},
#  {'name': 'Pa Chun il',
#   'alias': None,
#   'year_of_birth': 1954,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Typo',
#   'actual_name': 'Pak Chun il'},
#  {'name': 'Park Chun il',
#   'alias': None,
#   'year_of_birth': 1954,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Pak Chun il'},
#  {'name': 'Jo Yong Chol',
#   'alias': 'Cho, Yong Chol',
#   'year_of_birth': 1973,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': '-',
#   'actual_name': 'Jo Yong Chol'},
#  {'name': 'Jo Chol Yong',
#   'alias': None,
#   'year_of_birth': 1973,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Jo Yong Chol'},
#  {'name': 'Jo Ynog Chlo',
#   'alias': None,
#   'year_of_birth': 1973,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Jo Yong Chol'},
#  {'name': 'Joh Yong Chol',
#   'alias': None,
#   'year_of_birth': 1973,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Typo',
#   'actual_name': 'Jo Yong Chol'},
#  {'name': 'Cho Yong Chol',
#   'alias': None,
#   'year_of_birth': 1973,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Transcription',
#   'actual_name': 'Jo Yong Chol'},
#  {'name': 'Son Jong Hyok',
#   'alias': 'Son, Min',
#   'year_of_birth': 1980,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': '-',
#   'actual_name': 'Son Jong Hyok'},
#  {'name': 'SON JONG KYOK',
#   'alias': None,
#   'year_of_birth': 1980,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Typo',
#   'actual_name': 'Son Jong Hyok'},
#  {'name': 'Son Hyok Jong',
#   'alias': None,
#   'year_of_birth': 1980,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Son Jong Hyok'},
#  {'name': 'Son Jong Hoyk',
#   'alias': None,
#   'year_of_birth': 1980,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Son Jong Hyok'},
#  {'name': 'So Jon Hyok',
#   'alias': None,
#   'year_of_birth': 1980,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Typo',
#   'actual_name': 'Son Jong Hyok'},
#  {'name': 'Son Jung Hyok',
#   'alias': None,
#   'year_of_birth': 1980,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Transcription',
#   'actual_name': 'Son Jong Hyok'},
#  {'name': 'Son Chung Hyeok',
#   'alias': None,
#   'year_of_birth': 1980,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': None,
#   'nationality': 'North Korea',
#   'type_of_error': 'Transcription',
#   'actual_name': 'Son Jong Hyok'},
#  {'name': 'Son Mun San',
#   'alias': None,
#   'year_of_birth': 1951,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Son Mun San'},
#  {'name': 'Son San Mun',
#   'alias': None,
#   'year_of_birth': 1951,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Son Mun San'},
#  {'name': 'Son Mnu San',
#   'alias': None,
#   'year_of_birth': 1951,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Son Mun San'},
#  {'name': 'So Mun San',
#   'alias': None,
#   'year_of_birth': 1951,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Son Mun San'},
#  {'name': 'Son Moon San',
#   'alias': None,
#   'year_of_birth': 1951,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Transcription',
#   'actual_name': 'Son Mun San'}]

# %% [markdown]
# ## Generate 5 articles for each name in the dataframe, getting rid of duplicates

# %%
details_dictionary = [] #stores the dictionary of the person we will use for confidence checking
names_searched = []
queries = [] 
for item in df_dict:
    if item['actual_name'] in names_searched:
        print(f"not searching {item['actual_name']} because already searched")
        continue
    else:
        queries.append(search_articles_on_individual(item, 5))
        names_searched.append(item['actual_name'])
        details_dictionary.append(item)
# Out:
# SEARCHING THIS https://www.google.com/search?q=Chia+Teck+Leng+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Chia+Teck+Leng+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Chia Teck Leng because already searched
# not searching Chia Teck Leng because already searched
# SEARCHING THIS https://www.google.com/search?q=Teo+Cheng+Kiat+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-7a46695b8322> in <module>
#       7         continue
#       8     else:
# ----> 9         queries.append(search_articles_on_individual(item, 5))
#      10         names_searched.append(item['actual_name'])
#      11         details_dictionary.append(item)
#
# <ipython-input-9-9cd34cf66f79> in search_articles_on_individual(individual_dict, no_of_articles)
#      95
#      96                     # compute confidence score before accepting the article
# ---> 97                     conf_score = entity_recognition_scoring_each_article(individual_dict, text, names_list)
#      98                     if conf_score < 0.95:
#      99                         continue
#
# <ipython-input-8-517eb20fed44> in entity_recognition_scoring_each_article(input_info, text, names_list)
#      24         nationality_score = nationality_matching(parse(text), input_info['nationality'], input_info['name'])
#      25         gender_score = gender_matching(text, input_info['gender'], input_info['name'])
# ---> 26         age_score = age_matching(names_list,parse(text),input_info['year_of_birth'])
#      27
#      28         conf_score = (0.9071/100 * name_score) + (0.049973 * nationality_score) + (0.030293 * gender_score) + (0.012634 * age_score)
#
# <ipython-input-7-4971f9775b1a> in age_matching(name_dict, tags, age)
#      61         #if tag[1] == 'DATE':
#      62             #print(tag)
# ---> 63         if str(age) in tag[0] or str(age+1) in tag[0] or str(age-1) in tag[0]:
#      64             return 1
#      65     result = []
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
len(queries)
#len(details_dictionary)
# Out:
# 58

# %%
queries[0][0]
# Out:
# {'title': 'Guilty As Charged: Chia Teck Leng led a double life and cheated ...',
#  'time': '64 months ago',
#  'year_of_birth': 56,
#  'description': 'Asia Pacific Breweries executive Chia Teck Leng (left) cheated four banks of more than $117 million. His girlfriend...',
#  'link': 'https://www.straitstimes.com/singapore/courts-crime/guilty-as-charged-chia-teck-leng-led-a-double-life-and-cheated-banks-of',
#  'text': 'This story was first published in July 2015 in an e-book titled Guilty As Charged: 25 Crimes That Have Shaken Singapore Since 1965. A collaboration between The Straits Times and the Singapore Police Force, the e-book appeared in The Straits Times Star E-books app. Read the other crime stories here. (Warning: Some content in these stories may be disturbing for some individuals.)\n\nHigh-rolling hustler (2004)\n\n“Unremarkable” family man, who led double life as the darling of offshore casinos, cheated banks of millions\n\nLiving in a Serangoon Road condominium with his wife and two teenage sons — Chia Teck Leng appeared to most as an unremarkable family man, with all the trappings of upper middle-class Singapore. But unbeknownst to his friends and family, Chia secretly led a double life as a high-rolling hustler, complete with flashy cars, luxury apartments and a girlfriend half his age.\n\nHe was the darling of offshore casinos — gambling operators would personally fly him in on private jets so he could have a flutter in their betting halls.\n\nTo feed and fund his gambling addiction, he swindled four foreign banks out of $117 million from 1999 to 2003, using his position as the financial manager of Asia Pacific Breweries (APB). The case at that time was Singapore’s biggest involving commercial fraud.\n\nIn 2004, the then 44-year-old was sentenced to 42 years in jail by High Court Judge Tay Yong Kwang — the longest for a case of commercial fraud.\n\n“Bankers knocking on his door were there to meet the man… to forge a business relationship, but the man they met was unfortunately in the business of forgery,” said Judge Tay at the sentencing.\n\nChia had been a compulsive gambler since at least 1994, when he was a financial controller with Swire Pacific Offshore, a marine services company.\n\nHe had plunged deep into debt during 1995 to 1996 and owed several banks about $100,000 in the form of overdrafts and credit card dues. But fortune smiled on him the next year when he began visiting Star Cruise ships almost every fortnight, to try his luck at the gambling tables.\n\nHe won on several occasions and was offered a credit line of $75,000. In less than a year, his winnings grew to about $1 million.\n\nHowever, the tides turned in August 1998. In a gambling spree that lasted a fortnight, he not only lost all his previous winnings, but racked up new debts as well.\n\nBy the time he joined APB in 1999, the debts had mounted sky-high, and he was a desperate man. He trained his sights on four foreign banks, one after the other — Skandinaviska Enskilda Banken (SEB), Sumitomo Mitsui Banking Corporation (SMBC), the Mizuho Corporate Bank and the Bayerische Hypo-und Vereinsbank Aktiengesellschaft (HVB).\n\nSubmitting forged documents, he was able to open accounts in APB’s name, with himself as the sole signatory. With SEB he had a credit facility for $500,000 — which he intended to use for himself.\n\nMeanwhile, APB had no idea of what its finance manager was doing behind its back. Chia remained in sole control of all these accounts by forging director board resolutions that authorised him to receive the credit and loan facilities provided, sign all transactions and operate the bank accounts on behalf of APB.\n\nTo forge the signatures of the various directors of APB, he obtained specimens from annual reports and internal documents. He practised the signatures till he was sure they would pass muster.\n\nChia’s modus operandi was to draw money from SMBC, Mizuho and HVB, and transfer it to the SEB account. From there, the money was siphoned into his two personal accounts with DBS before it was remitted to casinos in Australia, Britain, Hong Kong, Malaysia and the Philippines.\n\nHe rolled over funds provided by the banks, making timely deposits to each account whenever repayments were due, thus creating the impression of a credit-worthy customer.\n\nDuring a crunch situation in November 1999, he even withdrew $53 million from an AP ...
#  'sentiment?': {'neg': 0.453, 'neu': 0.495, 'pos': 0.052, 'compound': -1.0},
#  'names_list': Counter({'Chia Teck Leng': 4,
#           'Chia': 10,
#           'Tay Yong Kwang': 1,
#           'Tay': 1,
#           'Li Jin': 2,
#           'Li': 2,
#           'Arthur Andersen': 1,
#           'Chu Chiao-Ling': 1,
#           'Skandinaviska Enskilda Banken': 1,
#           'Belinda Ang': 1,
#           'Guilty': 1})}

# %%
#for each item in queries, make them into dataframe and append each other together


#def entity_recognition_scoring(input_info, list_of_article_dicts):
dataframes = []



for i in range(1,len(queries)):
    details = details_dictionary[i]
    query = queries[i]
    
    temp_df = pd.DataFrame(entity_recognition_scoring(details, query))
    dataframes.append(temp_df)

#main_test_df

# %%
main_test_df = pd.DataFrame(entity_recognition_scoring(details_dictionary[0], queries[0]))

# %%
for item in dataframes:
    main_test_df = main_test_df.append(item)
    
main_test_df
# Out:
#                                                 title           time  \
# 0   Guilty As Charged: Chia Teck Leng led a double...  64 months ago
# 1   Guilty As Charged: Chia Teck Leng led a double...  64 months ago
# 2   Guilty As Charged: Chia Teck Leng led a double...  64 months ago
# 3   Accountant who embezzled $40m a compulsive gam...  28 months ago
# 4   Accountant who embezzled $40m a compulsive gam...  28 months ago
# ..                                                ...            ...
# 10  Former South Korean president sentenced to prison  10 months ago
# 11  Former South Korean president sentenced to prison  10 months ago
# 0   Asian American Elders Stand Resilient in the W...   2 months ago
# 1   Asian American Elders Stand Resilient in the W...   2 months ago
# 2   Asian American Elders Stand Resilient in the W...   2 months ago
#
#     year_of_birth                                        description  \
# 0              56  Asia Pacific Breweries executive Chia Teck Len...
# 1              56  Asia Pacific Breweries executive Chia Teck Len...
# 2              56  Asia Pacific Breweries executive Chia Teck Len...
# 3              59  While Ewe did not amass riches from his crimes...
# 4              59  While Ewe did not amass riches from his crimes...
# ..            ...                                                ...
# 10             47  The 89-year-old former president called Cho Ch...
# 11             47  The 89-year-old former president called Cho Ch...
# 0              70  Growing up in San Francisco, Victoria Eng, 28,...
# 1              70  Growing up in San Francisco, Victoria Eng, 28,...
# 2              70  Growing up in San Francisco, Victoria Eng, 28,...
#
#                                                  link  \
# 0   https://www.straitstimes.com/singapore/courts-...
# 1   https://www.straitstimes.com/singapore/courts-...
# 2   https://www.straitstimes.com/singapore/courts-...
# 3   https://www.straitstimes.com/singapore/courts-...
# 4   https://www.straitstimes.com/singapore/courts-...
# ..                                                ...
# 10  https://www.dw.com/en/former-south-korean-pres...
# 11  https://www.dw.com/en/former-south-korean-pres...
# 0   https://time.com/6082120/asian-american-elders...
# 1   https://time.com/6082120/asian-american-elders...
# 2   https://time.com/6082120/asian-american-elders...
#
#                                                  text  \
# 0   This story was first published in July 2015 in...
# 1   This story was first published in July 2015 in...
# 2   This story was first published in July 2015 in...
# 3   SINGAPORE - Certified public accountant Ewe Pa...
# 4   SINGAPORE - Certified public accountant Ewe Pa...
# ..                                                ...
# 10  Former South Korean president Chun Doo-hwan wa...
# 11  Former South Korean president Chun Doo-hwan wa...
# 0   As the daughter of immigrants from China, grow...
# 1   As the daughter of immigrants from China, grow...
# 2   As the daughter of immigrants from China, grow...
#
#                                            sentiment?  \
# 0   {'neg': 0.453, 'neu': 0.495, 'pos': 0.052, 'co...
# 1   {'neg': 0.453, 'neu': 0.495, 'pos': 0.052, 'co...
# 2   {'neg': 0.453, 'neu': 0.495, 'pos': 0.052, 'co...
# 3   {'neg': 0.322, 'neu': 0.648, 'pos': 0.03, 'com...
# 4   {'neg': 0.322, 'neu': 0.648, 'pos': 0.03, 'com...
# ..                                                ...
# 10  {'neg': 0.661, 'neu': 0.303, 'pos': 0.036, 'co...
# 11  {'neg': 0.661, 'neu': 0.303, 'pos': 0.036, 'co...
# 0   {'neg': 0.179, 'neu': 0.741, 'pos': 0.079, 'co...
# 1   {'neg': 0.179, 'neu': 0.741, 'pos': 0.079, 'co...
# 2   {'neg': 0.179, 'neu': 0.741, 'pos': 0.079, 'co...
#
#                                            names_list  name_matching_score  \
# 0   {'Chia Teck Leng': 4, 'Chia': 10, 'Tay Yong Kw...                  100
# 1   {'Chia Teck Leng': 4, 'Chia': 10, 'Tay Yong Kw...                  100
# 2   {'Chia Teck Leng': 4, 'Chia': 10, 'Tay Yong Kw...                  100
# 3   {'Chia Teck Leng': 2, 'Ewe Pang Kooi': 1, 'Ewe...                  100
# 4   {'Chia Teck Leng': 2, 'Ewe Pang Kooi': 1, 'Ewe...                  100
# ..                                                ...                  ...
# 10  {'Cho Chul-hyun': 3, 'Kim Young-sam': 2, 'Chun...                  100
# 11  {'Cho Chul-hyun': 3, 'Kim Young-sam': 2, 'Chun...                  100
# 0   {'Victoria Eng': 2, 'Elizabeth': 6, 'Donald Tr...                  100
# 1   {'Victoria Eng': 2, 'Elizabeth': 6, 'Donald Tr...                  100
# 2   {'Victoria Eng': 2, 'Elizabeth': 6, 'Donald Tr...                  100
#
#     nationality_matching_score  gender_matching_score  age_matching_score
# 0                          1.0               0.901961                   0
# 1                          1.0               0.901961                   0
# 2                          1.0               0.901961                   0
# 3                          1.0               0.000000                   0
# 4                          1.0               0.000000                   0
# ..                         ...                    ...                 ...
# 10                        -1.0               0.000000                   0
# 11                        -1.0               0.000000                   0
# 0                          0.0               0.166667                   1
# 1                          0.0               0.166667                   1
# 2                          0.0               0.166667                   1
#
# [732 rows x 12 columns]

# %%
# only unique links in df
test = main_test_df.drop_duplicates(subset=['link'])

# %%
test.to_excel('test_data.xlsx')
