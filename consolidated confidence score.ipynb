# %%
import jellyfish
from fuzzywuzzy import fuzz
import pandas as pd
import numpy as np
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import requests
from newspaper import Article
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
import dateutil.parser as parser
from geopy.geocoders import Nominatim
import pycountry
import time
from datetime import date
from dateutil.relativedelta import relativedelta
import pinyin

nlp = en_core_web_sm.load()
nltk.download('vader_lexicon')

df = pd.read_excel("NUS sample names_V2.xlsx", engine="openpyxl")
df = df.where(pd.notnull(df), None)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Name to be screened must be in English
# Alias names can only handle Chinese characters , else return None
def preprocess_df_to_dict(df):
    def get_year(date):
        try:
            parser_obj = parser.parse(str(date))
            return parser_obj.year
        except:
            return None

    def get_month(date):
        if len(str(date))>4:
            try:
                return parser.parse(str(date)).month
            except:
                return None
        else:
            return None
            
    def get_day(date):
        if len(str(date))>4:
            try:
                return parser.parse(str(date)).day
            except:
                return None
        else:
            return None
    
    def isEnglish(s):
        try:
            s.encode(encoding='utf-8').decode('ascii')
        except UnicodeDecodeError:
            return False
        else:
            return True    
    
    df_dict_list = df.to_dict('records')
    cleaned_dict_list = []
    for record in df_dict_list:
        
        alias = record['Alias name']
        if alias is not None:
            alias_is_english = isEnglish(alias)
            if alias_is_english is False:
                try:
                    alias = pinyin.get(alias, format='strip', delimiter=' ')
                except:
                    alias = None
        current_record = {
            'name': record['Name to be screened'],
            'alias' : alias,
            'year_of_birth': get_year(record['Date of birth']),
            'month_of_birth': get_month(record['Date of birth']),
            'day_of_birth': get_day(record['Date of birth']),
            'gender': record['Gender'],
            'nationality': record['Nationality'],
            ### delete these later on, for testing only###
            'type_of_error': record['Type of variation (if any)'],
            'actual_name': record['Actual name'],
        }
        cleaned_dict_list.append(current_record)
    return cleaned_dict_list

# %%
df_dict = preprocess_df_to_dict(df)
test_record_1 = df_dict[0]
test_record_18 = df_dict[15]
print(test_record_18)
# Out:
# {'name': 'Lange Vivian', 'alias': None, 'year_of_birth': 1997, 'month_of_birth': None, 'day_of_birth': None, 'gender': 'Female', 'nationality': 'Singapore', 'type_of_error': '-', 'actual_name': 'Lange Vivian'}

# %% [markdown]
# # Web Scraper

# %%
# Main Function
def search_articles_on_individual(individual_dict, no_of_articles=10):
    def generate_link(person_dict, attributes_used = ['name'], keywords=['crimes', 'sentenced']):
        link_start = "https://www.google.com/search?q="
        link_end = "&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2" 
        link_query = ""

        for attributes in attributes_used:
            temp_attr = person_dict[attributes]
            if temp_attr is not None:
                temp_attr = str(temp_attr)
                link_query += temp_attr.replace(' ', '+') + '+'       
                
        links = []
        for keyword in keywords:
            temp_search_link = link_start + link_query + keyword + link_end + "&num=" + str(no_of_articles)
            links.append(temp_search_link)
        return links
    
    def article_extraction(link):
        article = Article(link)
        article.download()
        try:
            article.parse()
        except:
            pass
        return article.text

    def parse(text):
        #try:     
        doc = nlp(text)
        tags = [[X.text, X.label_] for X in doc.ents]
        labels = [x.label_ for x in doc.ents]
        items = [x.text for x in doc.ents]

        return tags

    def find_names(tags):
        names = []
        for tag in tags:
            if tag[1] == 'PERSON':
                names.append(tag[0])
        return names

    def sentiment_analysis(text):
        return vader.polarity_scores(text)
    
    def time_to_months(time):
        if 'weeks' in time:
            return 0
        else:
            return int(time.split(' month')[0])

    search_links = generate_link(individual_dict)
    
    unique_links_checker = []
    
    output = []
    for x in search_links:
        print("SEARCHING THIS", x)
        req = Request(x, headers = {'User-Agent': 'Mozilla/5.0'})

        webpage = urlopen(req).read()

        with requests.Session() as c:
            soup = BeautifulSoup(webpage, 'html5lib')
            #print(soup)
            for item in soup.find_all('div', attrs = {'class': "ZINbbc xpd O9g5cc uUPGi"}):
                current_dict = {}
                raw_link = (item.find('a', href = True)['href'])
                try:
                    link = (raw_link.split("/url?q=")[1]).split('&sa=U&')[0]
                except IndexError as e1:
                    continue
                if link not in unique_links_checker and item:
                    unique_links_checker.append(link)
                    title = item.find('div',attrs = {'class': 'BNeawe vvjwJb AP7Wnd'})
                    if title == None:
                        continue
                    title = title.get_text()
                    description  = (item.find('div',attrs = {'class': 'BNeawe s3v9rd AP7Wnd'}).get_text())
                    time = description.split(" · ")[0]
                    #print(description)
                    descript = description.split(" · ")[1]

                    # compute confidence score before accepting the article
                    current_dict['title'] = title
                    current_dict['time'] = time
                    try:
                        current_dict['year_of_birth'] = (date.today() - relativedelta(months = time_to_months(time))).year - individual_dict['year_of_birth']
                    except TypeError as e1:
                        current_dict['year_of_birth'] = 0
                    except ValueError as e2:
                        current_dict['year_of_birth'] = 0
                    current_dict['description'] = descript
                    current_dict['link'] = link
                    current_dict['text'] = article_extraction(link)
                    current_dict['sentiment?'] = sentiment_analysis(article_extraction(link))
                    
                    
                    parsed_description = parse(description)
                    names_in_description = find_names(parsed_description)
                    
                    parsed_text = parse(article_extraction(link))
                    names_in_text = find_names(parsed_text)

                    names_list = Counter(names_in_description + names_in_text)
                    current_dict['names_list'] = names_list
                    
                    output.append(current_dict)
                else:
                    pass
    return output

new_words = {
    'crushes': 10,
    'beats': 5,
    'misses': -5,
    'trouble': -10,
    'falls': -100,
    'bankrupt': -100,
    'fraud': -100,
    'crime': -100,
    'prison': -100,
    'embezzlement': -100,
    'money_trail':-100,
    'jail': -100,
    'sentenced':-100,
    'forfeiture': -100,
    'ill-gotten gain':-100,
    'laundering':-100
}

vader = SentimentIntensityAnalyzer()

vader.lexicon.update(new_words)

# %%
def entity_recognition_scoring(input_info, list_of_article_dicts):
    output = []
    input_name = input_info['name']

    for article in list_of_article_dicts:
        article_names_list = article['names_list'].most_common() 
        matched = False
        
        for each_name, each_count in article_names_list: ## as of now checking all names within the article, should we limit to e.g. top 3/5?
            if len(each_name.split()) == 1 and each_name in input_name:
                score = 100 ## if surname matches, default match score 100 
            else: 
                try: 
                    score = ER_name_matching(input_name, each_name)
                except ValueError as e:
                    pass
            if score is not None:
                matched = True
            if matched:
                break
     
        if matched:
            # keep article
            article['name_matching_score'] = score

            # nationality matching score
            article ['nationality_matching_score'] = nationality_matching(parse(article['text']), input_info['nationality'], input_info['name'])

            # gender matching score
            article ['gender_matching_score'] =gender_matching(article['text'], input_info['gender'], input_info['name'])
            
            article['age_matching_score'] = age_matching(article['names_list'],parse(article['text']),article['year_of_birth'])
            #print(article['year_of_birth'])

            output.append(article)
    return output

# %%
test_query = search_articles_on_individual(test_record_18, 10)
pd.DataFrame(test_query)
# Out:
# SEARCHING THIS https://www.google.com/search?q=Lange+Vivian+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num
# 9   https://www.mlive.com/news/2021/06/first-2021-...
# 10  https://the-riotact.com/bernard-collaery-appea...
# 11  https://bravewords.com/news/def-leppard-guitar...
# 12  https://www.capjournal.com/news/feds-give-mexi...
# 13  https://www.mandurahmail.com.au/story/5837126/...
# 14  https://www.walesonline.co.uk/lifestyle/nostal...
# 15  https://www.thesun.co.uk/news/12890764/queens-...
# 16  https://clarksvillenow.com/local/over-200000-i...
# 17  https://www.thecut.com/article/is-working-from...
# 18  https://www.twincities.com/2020/06/13/top-grad...
# 19  https://kdhnews.com/centerforpolitics/incumben...
#
#                                                  text  \
# 0   SINGAPORE - A 23-year-old woman is the first p...
# 1
# 2   Authorities in the city-state have charged a 2...
# 3   The Atlanta shootings that killed eight people...
# 4
# 5   Gornick’s interviewees describe how communism ...
# 6   Local Weather Alerts Alpena County There are c...
# 7   Accustomed to asking the questions, NewsMD hea...
# 8
# 9   MUSKEGON, MI – The Miss Michigan scholarship p...
# 10  Whistleblower Bernard Colleary has launched a ...
# 11  Sweetwater’s Nick Bowcott is joined by Phil Co...
# 12  Country\n\nUnited States of America US Virgin ...
# 13  latest-news, court, mandurah\n\nA 30-year-old ...
# 14  Fancy a trip down memory lane? Invalid Email S...
# 15  EVERY year the Queen's Birthday Honours list r...
# 16  CLARKSVILLE, Tenn. (CLARKSVILLENOW) – Over $20...
# 17  Photo: Getty Images\n\nHot Bod is a weekly exp...
# 18  AFSA, Vadnais Heights\n\nMadeline Randall\n\nP...
# 19  1. Yes. There should be absolute certainty tha...
#
#                                            sentiment?  \
# 0   {'neg': 0.439, 'neu': 0.553, 'pos': 0.008, 'co...
# 1   {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound...
# 2   {'neg': 0.589, 'neu': 0.382, 'pos': 0.029, 'co...
# 3   {'neg': 0.196, 'neu': 0.78, 'pos': 0.023, 'com...
# 4   {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound...
# 5   {'neg': 0.066, 'neu': 0.767, 'pos': 0.167, 'co...
# 6   {'neg': 0.148, 'neu': 0.671, 'pos': 0.181, 'co...
# 7   {'neg': 0.042, 'neu': 0.869, 'pos': 0.09, 'com...
# 8   {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound...
# 9   {'neg': 0.071, 'neu': 0.809, 'pos': 0.12, 'com...
# 10  {'neg': 0.211, 'neu': 0.702, 'pos': 0.088, 'co...
# 11  {'neg': 0.026, 'neu': 0.934, 'pos': 0.04, 'com...
# 12  {'neg': 0.0, 'neu': 0.957, 'pos': 0.043, 'comp...
# 13  {'neg': 0.637, 'neu': 0.357, 'pos': 0.006, 'co...
# 14  {'neg': 0.404, 'neu': 0.565, 'pos': 0.031, 'co...
# 15  {'neg': 0.293, 'neu': 0.618, 'pos': 0.088, 'co...
# 16  {'neg': 0.527, 'neu': 0.451, 'pos': 0.022, 'co...
# 17  {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound...
# 18  {'neg': 0.115, 'neu': 0.821, 'pos': 0.064, 'co...
# 19  {'neg': 0.094, 'neu': 0.705, 'pos': 0.201, 'co...
#
#                                            names_list
# 0   {'Lange Vivian': 1, 'Lange': 3, 'Toa Payoh and...
# 1                   {'Jessica Lange': 1, 'Vivian': 1}
# 2                                 {'Vivian Lange': 2}
# 3   {'Vivian Shaw': 1, 'Courtney Sato': 1, 'Sato': 2}
# 4                             {'Vivian': 1, 'Ben': 1}
# 5   {'Vivian Gornick': 1, 'Lange': 1, 'Gornick': 5...
# 6   {'Vivian Dyer': 1, 'Pellston Alyssa Byrne': 1,...
# 7   {'Vivian Williams': 1, 'Andre Crockett': 1, 'S...
# 8                     {'Hill': 1, 'Vivian Howard': 1}
# 9   {'Nancy Anne Fleming Lange': 2, 'Rivard': 2, '...
# 10  {'Bernard Colleary': 2, 'Witness K': 1, 'Canbe...
# 11  {'Mutt Lange': 3, 'Joe Elliott': 2, 'Rick Alle...
# 12  {'Roberto Lange': 1, 'Barbuda Argentina': 1, '...
# 13  {'Dawson': 5, 'Matthew Rhys Dawson': 1, 'Mick ...
# 14  {'Eric Lange': 3, 'Invalid Email Something': 1...
# 15  {'Dr Antony Vivian': 1, 'Marcus Rashford': 1, ...
# 16  {'Vivian Hurn': 1, 'Derek Eugene Summers': 1, ...
# 17  {'Vivian Lee': 2, 'Getty Images
#
# ': 1, 'Franz ...
# 18  {'Reanna Knutson': 2, 'Bryanna Lackner': 2, 'E...
# 19  {'Killeen Police Detective Fred Harris': 1, 'T...

# %% [markdown]
# # Name Matching

# %%
def ER_name_matching(name1, name2):
    def split_name_list(name):
        name = name.lower()
        output = name.split(" ")
        return output

    def preprocess_name(names_dict, word):
        for key, value in names_dict.items():
            if word in value:
                return key
        else:
            return word

    def stitch_name(list1):
        output = ''
        for x in range(len(list1)):
            if x==0:
                output += list1[x]
            else:
                output += ' ' + list1[x]
        return output

    def phonetic_comparison(list1, list2):
        meta_list1 = []
        meta_list2 = []
        nysiis_list1 = []
        nysiis_list2 = []
        for name_1 in list1:
            meta_list1.append(jellyfish.metaphone(name_1))
            nysiis_list1.append(jellyfish.nysiis(name_1))
        for name_2 in list2:
            meta_list2.append(jellyfish.metaphone(name_2))
            nysiis_list2.append(jellyfish.nysiis(name_2))
        if (set(meta_list1) == set(meta_list2)) or (set(nysiis_list1) == set(nysiis_list2)):
            return True
        else:
            return False
    
    def excel_to_dict(excel_file):
        excel_df = pd.read_excel(excel_file)
        excel_df.value.apply(str)
        before_transformation = dict(zip(excel_df.key, excel_df.value))
        dictionary = {key: [val for val in value.split(',')] for key, value in before_transformation.items()}
        return dictionary
            
    names_dict = excel_to_dict('names_dict.xlsx') 
    
    # START #
    ### Change this if needed ###
    threshold = 89
    #############################
    
    split_list_1 = split_name_list(name1)
    split_list_2 = split_name_list(name2) 
 
    
    for i in range(len(split_list_1)):
        split_list_1[i] = preprocess_name(names_dict, split_list_1[i])        
    for i in range(len(split_list_2)):
        split_list_2[i] = preprocess_name(names_dict, split_list_2[i])
    
    stitched_name1 = stitch_name(split_list_1)
    stitched_name2 = stitch_name(split_list_2)
    
    # 1st layer of testing: Token Sort Ratio with threshold
    score1 = fuzz.token_sort_ratio(stitched_name1, stitched_name2)
    if score1 >= threshold:
        # score_list.append(score1)
        return score1
        # do something
# 4) 2nd layer of testing - Metaphone and NYSIIS phonetic encoding - DONE
    else: 
        matched_phonetic = phonetic_comparison(split_list_1, split_list_2)
        if matched_phonetic:
            return threshold # assumption that phonetic match will give threshold score
        else: 
            return None
    
    try:
        return score1
    except:
        pass

# %% [markdown]
# # Nationality Matching

# %%
from geopy.exc import GeocoderServiceError

# hlpr func: get country by cities, states name
def get_country(gpe):
    geolocator = Nominatim(user_agent = "geoapiExercises")
    location = geolocator.geocode(gpe)
    if location:
        loc_lst = location.address.split(',')
        return loc_lst[-1]
    return None

# hlpr func: return a list of countries names
def countries():
    return list(map(lambda x: x.name, list(pycountry.countries)))

# hlpr func: return True if name countains country name
def contain_country(word, ctry_lst):
    for ctry in ctry_lst:
        if ctry.lower() in word.lower():
            return True
    return False

# hlpr func: extract entities with tag 'GPE', 'ORG', 'NORP'
def search_target_ent(tags):
    country_lst = countries()
    tag_lst = []
    for i in range(len(tags)):
        if tags[i][1] == 'GPE' or tags[i][1] == 'ORG' or tags[i][1] == 'NORP':
            if contain_country(tags[i][0], country_lst):
                tag_lst.append(tags[i])
    return tag_lst

# hlpr func: return the odd of the person's nationality in the article is nat
def calc_odd_nationality(nat,lst):
    try:
        result = []
        for tag in lst:
            if tag[0] is not None and nat is not None:
                if nat.lower() in tag[0].lower():
                    result.append(tag)
                    continue
            try:
                if tag[1] == 'GPE' and (get_country(tag[0]) is not None and nat is not None):
                    if get_country(tag[0]).lower() == nat.lower():
                        result.append(tag)
            except GeocoderServiceError as e:
                pass
        prob = 1 if ((len(lst) - len(result)) == 0 and len(result) > 0) else (len(result) / (len(lst) - len(result)))
        prob = 1 if prob > 1 else prob
        return prob
    except TypeError as e:
        pass

# hlpr func: return True if name fuzzy matching score > 80
def is_target(name, article_name):
    return fuzz.partial_ratio(name, article_name) > 80

# the main function for nationality matching
# return odd if target tags found else return -1
def nationality_matching(tags, nationality, person):
    result = []
    try:
        for i in range(len(tags)):
            #if second item is a name
            if tags[i][1] == 'PERSON':
                
                # check if is target
                if is_target(person, tags[i][0]):
                    search = search_target_ent(tags)
                
                    if len(search) != 0:
                        return calc_odd_nationality(nationality, search)
        return -1
    except IndexError as e:
        pass

# hlpr func: parse text to tags
def parse(text):
        #try:     
        doc = nlp(text)
        tags = [[X.text, X.label_] for X in doc.ents]
        labels = [x.label_ for x in doc.ents]
        items = [x.text for x in doc.ents]

        return tags

# %% [markdown]
# # Gender Matching

# %%
# hlpr func: return True if token is a name and subject
def is_name_subj(token):
    return token.dep_ =='nsubj' and token.pos_ == 'PROPN'

def is_part_of_name(token):
    return (token.dep_ =='nsubj' or token.dep_ =='compound') \
        and token.pos_ == 'PROPN'

# hlpr func: return True if the token is a determiner: his, her, hers
def is_det(token):
    return token.pos_ == 'DET' and (token.dep_ == 'poss' or token.dep_ == 'attr')

# hlpr func: return True if the token is a pronoun: he, she, herself, himself
def is_pron(token):
    return token.pos_ == 'PRON' and \
        (token.dep_ == 'nsubj' or token.dep_ == 'nsubjpass' or token.dep_ == 'pobj' or token.dep_ == 'dobj')

# hlpr func: return the probability of the gender in article to the true gender
def calc_prob_gender(pron_lst, gender):
    male_pron = ['he', 'his', 'himself', 'him']
    female_pron = ['she', 'her', 'herself', 'hers']
    n_target = 0
    gdr_pron = []
    
    if gender.lower() == 'male':
        gdr_pron = male_pron
    else:
        gdr_pron = female_pron
        
    for pron in pron_lst:
        if pron in gdr_pron:
            n_target += 1
    return n_target / len(pron_lst) if len(pron_lst) else 0

# the main function in gender matching
def gender_matching(text, gender, name):
    try:
        pron_lst = ['he', 'his', 'himself', 'him', 'she', 'her', 'herself', 'hers']
        name_str = ''
        target_name = name.replace(" ", "")
        target_found = False
        res_lst = []
        
        # text tagging
        doc = nlp(text)
        
        i = 0
        while i < len(doc):
            # search for target name of subject form
            if is_name_subj(doc[i]):
                end_name = i
                start_name = i
                while is_part_of_name(doc[start_name]):
                    start_name -= 1
                start_name += 1
                while start_name <= end_name:
                    name_str += doc[start_name].text
                    start_name += 1
                i += 1
            if is_target(name_str, target_name):
                target_found = True
            else:
                name_str = ''
                target_found = False
            
            # if target name is found, search for pronouns, break if another name is found
            while target_found:
                if is_name_subj(doc[i]):
                    target_found = False
                    name_str = ''
                    break
                if is_det(doc[i]) or is_pron(doc[i]):
                    if (doc[i].text).lower() in pron_lst:
                        res_lst.append((doc[i].text).lower())
                        break
                i += 1
            if is_name_subj(doc[i]):
                continue
            i += 1    
    except IndexError as e:
        pass
    return calc_prob_gender(res_lst, gender)

# %% [markdown]
# ## Age Matching

# %%
useless_dates = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday','yesterday','today']

#index is index of person
def forward_searcher(index,tags):
    for i in range(index,len(tags)):
        if tags[i][1] == 'DATE' and tags[i][0] not in useless_dates:
            return tags[i]
    return [None,None]

def backward_searcher(index,tags):
    i = index
    while i >= 0:
        if tags[i][1] == 'DATE' and tags[i][0] not in useless_dates:
            return tags[i]
        else:
            i -=1

def detect_age(age,lst):
    try:
        if lst[1] is not None and lst[2] is not None:
            date1 = lst[1][0]
            date2 = lst[2][0]
            if (str(age) in date1) or (str(age) in date2):
                return True
        else:

            if lst[1] == None:
                if str(age) in lst[2][0]:
                    return True

            if lst[2] == None:
                if str(age) in lst[1][0]:
                    return True
    except TypeError as e:
        pass
    
    
def confirm_age(lst,age,threshold):
    iterating_lst = []
    plus = 1
    minus = -1
    for i in range(threshold):
        iterating_lst.append(age+plus)
        plus += 1
    for i in range(threshold):
        iterating_lst.append(age+minus)
        minus -=1 
    iterating_lst.append(age)
    
    for j in iterating_lst:
        if str(j) in lst[1][0]:
            return 1
    return 0

def age_matching(name_dict,tags,age):
    '''
    tags: parse(text)
    age: desired age to check
    '''
    for tag in tags:
        #if tag[1] == 'DATE':
            #print(tag)
        if str(age) in tag[0] or str(age+1) in tag[0] or str(age-1) in tag[0]:
            return 1
    result = []
    try:
        for i in range(len(tags)):
            #if second item is a name

            
            if tags[i][1] == 'PERSON':
                if tags[i][0] in name_dict:

                    forward_age = forward_searcher(i,tags)
                    backwards_age = backward_searcher(i,tags)
                    new_list = [tags[i],forward_age,backwards_age]
                    #new_list = [tags[i-1],tags[i],tags[i+1]]
                    #print(new_list)

                    if detect_age(age,new_list) and tags[i][0] in name_list:

                        #print(new_list)
                        #result += new_list

                        if str(age) in new_list[1][0]:
                            #print('****************')
                            #print([tags[i], new_list[1]])
                            return(confirm_age([tags[i],new_list[1]],age,3))


                        elif str(age) in new_list[2][0]:
                            #print('****************')
                            #print([tags[i],new_list[2]])
                            return(confirm_age([tags[i],new_list[2]],age,3))
                        
        return 0
    except IndexError as e:
        pass

# %%
def entity_recognition_scoring(input_info, list_of_article_dicts):
    output = []
    input_name = input_info['name']

    for article in list_of_article_dicts:
        article_names_list = article['names_list'].most_common() 
        matched = False

        for each_name, each_count in article_names_list: ## as of now checking all names within the article, should we limit to e.g. top 3/5?
            if len(each_name.split()) == 1 and each_name in input_name:
                score = 100 ## if surname matches, default match score 100 
            else: 
                try: 
                    score = ER_name_matching(input_name, each_name)
                except ValueError as e:
                    pass
            if score is not None:
                matched = True
            if matched:
                break
     
        if matched:
            # keep article
            article['name_matching_score'] = score
            output.append(article)

            # nationality matching score
            article ['nationality_matching_score'] = nationality_matching(parse(article['text']), input_info['nationality'], input_info['name'])
            output.append(article)

            # gender matching score
            article ['gender_matching_score'] =gender_matching(article['text'], input_info['gender'], input_info['name'])
            output.append(article)
            
            article['age_matching_score'] = age_matching(article['names_list'],parse(article['text']),article['year_of_birth'])
            #print(article['year_of_birth'])
    
    return output
            
        
    ##### ADD IN SECONCARY IDENTIFIERS #######
    
    ##### ADD IN SCORING SYSTEM HERE #######

# %%
test_record_18
# Out:
# {'name': 'Lange Vivian',
#  'alias': None,
#  'year_of_birth': 1997,
#  'month_of_birth': None,
#  'day_of_birth': None,
#  'gender': 'Female',
#  'nationality': 'Singapore',
#  'type_of_error': '-',
#  'actual_name': 'Lange Vivian'}

# %%
name_matched = entity_recognition_scoring(test_record_18, test_query)
pd.DataFrame(name_matched)
# Out:
#                                                 title           time  \
# 0   Woman first to be charged under new anti-money...  15 months ago
# 1   Woman first to be charged under new anti-money...  15 months ago
# 2   Woman first to be charged under new anti-money...  15 months ago
# 3   Every Season Of American Horror Story Evan Pet...    2 weeks ago
# 4   Every Season Of American Horror Story Evan Pet...    2 weeks ago
# 5   Every Season Of American Horror Story Evan Pet...    2 weeks ago
# 6   Singapore Cracks Down on Unlicensed Crypto Sel...  15 months ago
# 7   Singapore Cracks Down on Unlicensed Crypto Sel...  15 months ago
# 8   Singapore Cracks Down on Unlicensed Crypto Sel...  15 months ago
# 9   American Horror Stories Episode 7 Explained by...    1 month ago
# 10  American Horror Stories Episode 7 Explained by...    1 month ago
# 11  American Horror Stories Episode 7 Explained by...    1 month ago
# 12  How Vivian Gornick Reinvigorated Political Wri...  17 months ago
# 13  How Vivian Gornick Reinvigorated Political Wri...  17 months ago
# 14  How Vivian Gornick Reinvigorated Political Wri...  17 months ago
#
#     year_of_birth                                        description  \
# 0              23  Lange Vivian was on Wednesday (June 24) charge...
# 1              23  Lange Vivian was on Wednesday (June 24) charge...
# 2              23  Lange Vivian was on Wednesday (June 24) charge...
# 3              24  American Horror Story has also given actors li...
# 4              24  American Horror Story has also given actors li...
# 5              24  American Horror Story has also given actors li...
# 6              23  ... of crime from victims of online scams, the...
# 11                            {'Vivian': 1, 'Ben': 1}                  100
# 12  {'Vivian Gornick': 1, 'Lange': 1, 'Gornick': 5...                  100
# 13  {'Vivian Gornick': 1, 'Lange': 1, 'Gornick': 5...                  100
# 14  {'Vivian Gornick': 1, 'Lange': 1, 'Gornick': 5...                  100
#
#     nationality_matching_score  gender_matching_score  age_matching_score
# 0                            1                      0                   1
# 1                            1                      0                   1
# 2                            1                      0                   1
# 3                           -1                      0                   0
# 4                           -1                      0                   0
# 5                           -1                      0                   0
# 6                           -1                      0                   1
# 7                           -1                      0                   1
# 8                           -1                      0                   1
# 9                           -1                      0                   0
# 10                          -1                      0                   0
# 11                          -1                      0                   0
# 12                          -1                      0                   0
# 13                          -1                      0                   0
# 14                          -1                      0                   0

# %%
name_matched
# Out:
# [{'title': 'Woman first to be charged under new anti-money laundering law',
#   'time': '15 months ago',
#   'year_of_birth': 23,
#   'description': 'Lange Vivian was on Wednesday (June 24) charged with one count of ... of crime from victims of online scams," a police spokesman said.',
#   'link': 'https://www.straitstimes.com/singapore/courts-crime/woman-first-to-be-charged-under-new-anti-money-laundering-law',
#   'text': 'SINGAPORE - A 23-year-old woman is the first person to be charged under a new law that fights money laundering and terrorism financing.\n\nLange Vivian was on Wednesday (June 24) charged with one count of providing payment services without a licence under the Payment Services Act.\n\nThe law, which also aims to strengthen consumer protection in the use of e-payments, was introduced on Jan 28.\n\nThe Singaporean allegedly provided a digital payment token service between Feb 27 and 28 this year.\n\nIn a statement on Tuesday, the police said that she allegedly received at least 13 fraudulent fund transfers this way.\n\nIn total, she is accused of receiving around $3,000 in her bank account.\n\nLange is said to have then used the proceeds to buy Bitcoin.\n\n"These transactions were done on the instruction of an unknown person in return for a commission.\n\n"The monies deposited in her bank account turned out to be proceeds of crime from victims of online scams," a police spokesman said.\n\nThe police did not reveal details of these scams.\n\nLange had earlier been charged with 10 counts of acting on behalf of a loan shark known only as "Boss".\n\nOn May 13 last year, Lange and another man are said to have gone to a Housing Board flat in Hougang to commit acts such as defacing the front door with paint.\n\nThey are also accused of targeting other flats at places such as Toa Payoh and Tampines. This went on until May 21 last year.\n\nLange\'s bail was set at $15,000 and her pre-trial conference will be held on July 22.\n\nIf convicted of the offence under the Payment Services Act, she can be jailed for up to three years and fined up to $125,000.\n\nFor each charge of acting on behalf of a loan shark, an offender can be jailed for up to five years, fined a maximum $50,000 and receive up to six strokes of the cane.\n\nLange cannot be caned, as she is a woman.',
#   'sentiment?': {'neg': 0.439,
#    'neu': 0.553,
#    'pos': 0.008,
#    'compound': -0.9998},
#   'names_list': Counter({'Lange Vivian': 1,
#            'Lange': 3,
#            'Toa Payoh and Tampines': 1}),
#   'name_matching_score': 100,
#   'nationality_matching_score': 1,
#   'gender_matching_score': 0,
#   'age_matching_score': 1},
#  {'title': 'Woman first to be charged under new anti-money laundering law',
#   'time': '15 months ago',
#   'year_of_birth': 23,
#   'description': 'Lange Vivian was on Wednesday (June 24) charged with one count of ... of crime from victims of online scams," a police spokesman said.',
#   'link': 'https://www.straitstimes.com/singapore/courts-crime/woman-first-to-be-charged-under-new-anti-money-laundering-law',
#   'text': 'SINGAPORE - A 23-year-old woman is the first person to be charged under a new law that fights money laundering and terrorism financing.\n\nLange Vivian was on Wednesday (June 24) charged with one count of providing payment services without a licence under the Payment Services Act.\n\nThe law, which also aims to strengthen consumer protection in the use of e-payments, was introduced on Jan 28.\n\nThe Singaporean allegedly provided a digital payment token service between Feb 27 and 28 this year.\n\nIn a statement on Tuesday, the police said that she allegedly received at least 13 fraudulent fund transfers this way.\n\nIn total, she is accused of receiving around $3,000 in her bank account.\n\nLange is said to have then used the proceeds to buy Bitcoin.\n\n"These transactions were done on the instruction of an unknown person in return for a commission.\n\n"The monies deposited in her bank account turned out to be proceeds of crime from victims of online scams," a police spokesman said.\n\nThe police did not reveal details of these scams.\n\nLange had earlier been charged with 10 counts of acting on behalf of a loan shark known only as "Boss".\n\nOn May 13 last year, Lange and another man are said to have gone to a Housing Board flat in Hougang to commit acts such as defacing the front door with paint.\n\nThey are also accused of targeting other flats at places such as Toa Payoh and Tampines. This went on until May 21 last year.\n\nLange\'s bail was set at $15,000 and her pre-trial conference will be held on July 22.\n\nIf convicted of the offence under the Payment Services Act, she can be jailed for up to three years and fined up to $125,000.\n\nFor each charge of acting on behalf of a loan shark, an offender can be jailed for up to five years, fined a maximum $50,000 and receive up to six strokes of the cane.\n\nLange cannot be caned, as she is a woman.',
#   'sentiment?': {'neg': 0.439,
#    'neu': 0.553,
#    'pos': 0.008,
#    'compound': -0.9998},
#   'names_list': Counter({'Lange Vivian': 1,
#            'Lange': 3,
#            'Toa Payoh and Tampines': 1}),
#   'name_matching_score': 100,
#   'nationality_matching_score': 1,
#   'gender_matching_score': 0,
#   'age_matching_score': 1},
#  {'title': 'Woman first to be charged under new anti-money laundering law',
#   'time': '15 months ago',
#   'year_of_birth': 23,
#   'description': 'Lange Vivian was on Wednesday (June 24) charged with one count of ... of crime from victims of online scams," a police spokesman said.',
#   'link': 'https://www.straitstimes.com/singapore/courts-crime/woman-first-to-be-charged-under-new-anti-money-laundering-law',
#   'text': 'SINGAPORE - A 23-year-old woman is the first person to be charged under a new law that fights money laundering and terrorism financing.\n\nLange Vivian was on Wednesday (June 24) charged with one count of providing payment services without a licence under the Payment Services Act.\n\nThe law, which also aims to strengthen consumer protection in the use of e-payments, was introduced on Jan 28.\n\nThe Singaporean allegedly provided a digital payment token service between Feb 27 and 28 this year.\n\nIn a statement on Tuesday, the police said that she allegedly received at least 13 fraudulent fund transfers this way.\n\nIn total, she is accused of receiving around $3,000 in her bank account.\n\nLange is said to have then used the proceeds to buy Bitcoin.\n\n"These transactions were done on the instruction of an unknown person in return for a commission.\n\n"The monies deposited in her bank account turned out to be proceeds of crime from victims of online scams," a police spokesman said.\n\nThe police did not reveal details of these scams.\n\nLange had earlier been charged with 10 counts of acting on behalf of a loan shark known only as "Boss".\n\nOn May 13 last year, Lange and another man are said to have gone to a Housing Board flat in Hougang to commit acts such as defacing the front door with paint.\n\nThey are also accused of targeting other flats at places such as Toa Payoh and Tampines. This went on until May 21 last year.\n\nLange\'s bail was set at $15,000 and her pre-trial conference will be held on July 22.\n\nIf convicted of the offence under the Payment Services Act, she can be jailed for up to three years and fined up to $125,000.\n\nFor each charge of acting on behalf of a loan shark, an offender can be jailed for up to five years, fined a maximum $50,000 and receive up to six strokes of the cane.\n\nLange cannot be caned, as she is a woman.',
#   'sentiment?': {'neg': 0.439,
#    'neu': 0.553,
#    'pos': 0.008,
#    'compound': -0.9998},
#   'names_list': Counter({'Lange Vivian': 1,
#            'Lange': 3,
#            'Toa Payoh and Tampines': 1}),
#   'name_matching_score': 100,
#   'nationality_matching_score': 1,
#   'gender_matching_score': 0,
#   'age_matching_score': 1},
#  {'title': "Every Season Of American Horror Story Evan Peters' Tate Has Appeared In",
#   'time': '2 weeks ago',
#   'year_of_birth': 24,
#   'description': 'American Horror Story has also given actors like Jessica Lange, ... the offspring of Tate and Vivian, who acted as the main villain in a...',
#   'link': 'https://screenrant.com/american-horror-story-show-tate-evan-peters-appearance/',
#   'text': '',
#   'sentiment?': {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0},
#   'names_list': Counter({'Jessica Lange': 1, 'Vivian': 1}),
#   'name_matching_score': 100,
#   'nationality_matching_score': -1,
#   'gender_matching_score': 0,
#   'age_matching_score': 0},
#  {'title': "Every Season Of American Horror Story Evan Peters' Tate Has Appeared In",
#   'time': '2 weeks ago',
#   'year_of_birth': 24,
#   'description': 'American Horror Story has also given actors like Jessica Lange, ... the offspring of Tate and Vivian, who acted as the main villain in a...',
#   'link': 'https://screenrant.com/american-horror-story-show-tate-evan-peters-appearance/',
#   'text': '',
#   'sentiment?': {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0},
#   'names_list': Counter({'Jessica Lange': 1, 'Vivian': 1}),
#   'name_matching_score': 100,
#   'nationality_matching_score': -1,
#   'gender_matching_score': 0,
#   'age_matching_score': 0},
#  {'title': "Every Season Of American Horror Story Evan Peters' Tate Has Appeared In",
#   'time': '2 weeks ago',
#   'year_of_birth': 24,
#   'description': 'American Horror Story has also given actors like Jessica Lange, ... the offspring of Tate and Vivian, who acted as the main villain in a...',
#   'link': 'https://screenrant.com/american-horror-story-show-tate-evan-peters-appearance/',
#   'text': '',
#   'sentiment?': {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0},
#   'names_list': Counter({'Jessica Lange': 1, 'Vivian': 1}),
#   'name_matching_score': 100,
#   'nationality_matching_score': -1,
#   'gender_matching_score': 0,
#   'age_matching_score': 0},
#  {'title': 'Singapore Cracks Down on Unlicensed Crypto Sellers',
#   'time': '15 months ago',
#   'year_of_birth': 23,
#   'description': '... of crime from victims of online scams, the statement said. ... Local newspaper «The Straits Times» identified the woman as Vivian Lange,...',
#   'link': 'https://www.finews.asia/finance/32107-singapore-cracks-down-on-unlicensed-crypto-sellers-payment-services-act-mas',
#   'text': 'Authorities in the city-state have charged a 23-year-old woman under the Payment Services Act, for carrying on a business of providing payment services without a licence.\n\nThe woman had allegedly provided a digital payment token service between February 27 and 28 this year, by receiving at least 13 fraudulent fund transfers amounting to S$3,350 ($2,406) in her bank account, which was then used to purchase bitcoin, the Singapore Police Force said in a statement on Wednesday.\n\nThe funds deposited in her bank account turned out to be proceeds of crime from victims of online scams, the statement said. According to the police, the woman does not have a licence to provide payment services in Singapore and is not an exempt payment service provider under the Payment Services Act.\n\nLocal newspaper «The Straits Times» identified the woman as Vivian Lange, who had earlier been charged with 10 counts of acting on behalf of a loan shark known only «Boss.»\n\nAnti-Money Laundering\n\nThe Payment Services Act, introduced in January 2020, aims to provide for regulatory certainty and consumer safeguards, while encouraging innovation and growth of payment services and fintech.\n\nBesides bringing crypto firms into the regulatory fold, the law gives the Monetary Authority of Singapore formal supervisory powers for cybersecurity risks and controls on money laundering and terrorism financing\n\nLange faces a fine of up to $125,000 or imprisonment for a term of up to three years, or both.',
#   'sentiment?': {'neg': 0.589,
#    'neu': 0.382,
#    'pos': 0.029,
#    'compound': -0.9999},
#   'names_list': Counter({'Vivian Lange': 2}),
#   'name_matching_score': 100,
#   'nationality_matching_score': -1,
#   'gender_matching_score': 0,
#   'age_matching_score':
),
#   'name_matching_score': 100,
#   'nationality_matching_score': -1,
#   'gender_matching_score': 0,
#   'age_matching_score': 1},
#  {'title': 'American Horror Stories Episode 7 Explained by Dylan McDermott',
#   'time': '1 month ago',
#   'year_of_birth': 24,
#   'description': "I would go upstairs and hang out in Vivian and Ben's bedroom. ... on American Horror Story, American Crime Story, and all the shows he does.",
#   'link': 'https://collider.com/american-horror-stories-episode-7-ending-explained-dylan-mcdermott-interview/',
#   'text': '',
#   'sentiment?': {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0},
#   'names_list': Counter({'Vivian': 1, 'Ben': 1}),
#   'name_matching_score': 100,
#   'nationality_matching_score': -1,
#   'gender_matching_score': 0,
#   'age_matching_score': 0},
#  {'title': 'American Horror Stories Episode 7 Explained by Dylan McDermott',
#   'time': '1 month ago',
#   'year_of_birth': 24,
#   'description': "I would go upstairs and hang out in Vivian and Ben's bedroom. ... on American Horror Story, American Crime Story, and all the shows he does.",
#   'link': 'https://collider.com/american-horror-stories-episode-7-ending-explained-dylan-mcdermott-interview/',
#   'text': '',
#   'sentiment?': {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0},
#   'names_list': Counter({'Vivian': 1, 'Ben': 1}),
#   'name_matching_score': 100,
#   'nationality_matching_score': -1,
#   'gender_matching_score': 0,
#   'age_matching_score': 0},
#  {'title': 'American Horror Stories Episode 7 Explained by Dylan McDermott',
#   'time': '1 month ago',
#   'year_of_birth': 24,
#   'description': "I would go upstairs and hang out in Vivian and Ben's bedroom. ... on American Horror Story, American Crime Story, and all the shows he does.",
#   'link': 'https://collider.com/american-horror-stories-episode-7-ending-explained-dylan-mcdermott-interview/',
#   'text': '',
#   'sentiment?': {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0},
#   'names_list': Counter({'Vivian': 1, 'Ben': 1}),
#   'name_matching_score': 100,
#   'nationality_matching_score': -1,
#   'gender_matching_score': 0,
#   'age_matching_score': 0},
#  {'title': 'How Vivian Gornick Reinvigorated Political Writing',
#   'time': '17 months ago',
#   'year_of_birth': 23,
#   'description': 'Vivian Gornick specializes in personal narrative. ... Lange explains why she was drawn to Marxism and the party: “The act of understanding...',
#   'link': 'https://newrepublic.com/article/157527/vivian-gornick-romance-american-communism-reinvigorated-political-writing',
#   'text': 'Gornick’s interviewees describe how communism saved them from despair, the rut of ill-paid, precarious work in bad conditions, the absence of hope for the future. It also introduced some of them to the joys of intellectual life, a transformative gift in itself. “God, I have never felt so free in my life as I did in those first days when I discovered Marx and the existence of my own mind at the same time,” says a Polish slaughterhouse worker who spent his workdays knee-deep in animal blood and shit. There could be a sense of victory and power, too: Several interviewees describe their participation in successful strikes and labor organizing—one of the most important achievements of the American Communist Party—as the highlight of their lives.\n\nRomance is heavily seasoned with psychoanalysis. As one might expect from a person who wrote an entire book, Fierce Attachments, about her enduringly close relationship with a difficult, love-obsessed, widowed mother, Gornick is especially interested in the role of parent-child relations in the conversion to communism. Sometimes it’s a desire to vindicate a working-class father’s suffering, to feel that his pain had meaning: The drudgery of everyday organizing becomes bearable because it is dedicated to his memory. Some subjects are drawn to communism because it compensates for inadequate parents. In other cases, Communist commitment stems from a Freudian excess of filial devotion, as in the case of Belle Rothman:\n\nBelle was the daughter of Max Rothman: cigar-maker and Communist. (Oh, these Communist women and their fathers!) Max looked like Trotsky, only better. Max thought like Lenin, only not quite so good. The passion of Max’s life was Communism. The passion of Belle’s life was Max.\n\nHere
to feel that his pain had meaning: The drudgery of everyday organizing becomes bearable because it is dedicated to his memory. Some subjects are drawn to communism because it compensates for inadequate parents. In other cases, Communist commitment stems from a Freudian excess of filial devotion, as in the case of Belle Rothman:\n\nBelle was the daughter of Max Rothman: cigar-maker and Communist. (Oh, these Communist women and their fathers!) Max looked like Trotsky, only better. Max thought like Lenin, only not quite so good. The passion of Max’s life was Communism. The passion of Belle’s life was Max.\n\nHere we encounter one of the weaknesses of Romance: Gornick’s insistence that she understands her subjects better than they do, that she can expose their false consciousness. “She hardly knows,” Gornick writes pityingly of Belle, “that the ‘we’ of her speech is not her husband and herself but her father and herself. Max and the Communist Party: that piercing, glowing rapture from which she would never recover and whose sources she would never uncover. Like Teresa penetrated by her angel’s arrow, Belle penetrated by Papa’s revolution.” Belle is cheated of the opportunity to be judged on her own words; a more skillful oral historian could have made insight about Belle’s daddy issues available without indulging in such clumsy editorializing. Here and elsewhere in Romance, Gornick’s intrusive narrative approach reminded me of a heavy-handed psychoanalyst who brings everything, relentlessly, back to the Freudian menu, denying the possibility—the freedom—of speaking about big ideas without relating them to the specifics of childhood. Sometimes a cigar-maker is just a cigar-maker.\n\nRomance shows that psychoanalysis and political history don’t always mix well. The psychoanalytic focus on drives tends to empty the content from political commitment. Gornick suggests that Marxism was to Communists what Helen was to Paris, awakening an all-consuming passion, setting in motion “the most intense longings, longings buried in the unknowing self, longings that pierced to the mysterious, vulnerable heart at the center of that incoherent life within us, longings that had to do with the need to live a life of meaning.” Personal relationships certainly do play a substantial role in political commitment, and the search for meaning is a crucial part of the story, but it’s unfair to reduce political convictions to inchoate longings. Misguided though the Communist Party of the USA may have been, communism was a complex ideology with roots in substantive criticisms of capitalism. Besides, Paris’s longing was not mysterious: He wanted the most beautiful woman in the world.',
#   'sentiment?': {'neg': 0.066, 'neu': 0.767, 'pos': 0.167, 'compound': 0.9959},
#   'names_list': Counter({'Vivian Gornick': 1,
#            'Lange': 1,
#            'Gornick': 5,
#            'Marx': 1,
#            'Fierce Attachments': 1,
#            'Belle Rothman': 1,
#            'Max Rothman': 1,
#            'Max': 5,
#            'Trotsky': 1,
#            'Lenin': 1,
#            'Romance': 1,
#            'Teresa': 1,
#            'Helen': 1}),
#   'name_matching_score': 100,
#   'nationality_matching_score': -1,
#   'gender_matching_score': 0,
#   'age_matching_score': 0}]

# %%
df_dict
# Out:
# [{'name': 'Chia Teck Leng',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Chia Teck Leng'},
#  {'name': 'Teck Leng Chia',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Chia Teck Leng'},
#  {'name': 'Chia Tek Leng',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Chia Teck Leng'},
#  {'name': 'Teo Cheng Kiat',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Teo Cheng Kiat'},
#  {'name': 'Cheng Kiat Teo',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Teo Cheng Kiat'},
#  {'name': 'Teo Cheng Keat',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Teo Cheng Kiat'},
#  {'name': 'Teo Chen Kiat',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Typo',
#   'actual_name': 'Teo Cheng Kiat'},
#  {'name': 'Chong Hock Yen',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Chong Hock Yen'},
#  {'name': 'Hock Yen Chong',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Chong Hock Yen'},
#  {'name': 'Chong Hock Yan',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Chong Hock Yen'},
#  {'name': 'Lim Oon Kuin',
#   'alias': None,
#   'year_of_birth': 1943,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Lim Oon Kuin'},
#  {'name': 'Oon Kuin Lim',
#   'alias': None,
#   'year_of_birth': 1943,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Lim Oon Kuin'},
#  {'name': 'Lim Oon Quin',
#   'alias': None,
#   'year_of_birth': 1943,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Phonetic variations',
#   'actual_name': 'Lim Oon Kuin'},
#  {'name': 'Tan Wee Beng',
#   'alias': None,
#   'year_of_birth': 1977,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Tan Wee Beng'},
#  {'name': 'Tan Wee Bing',
#   'alias': None,
#   'year_of_birth': 1977,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Typo',
#   'actual_name': 'Tan Wee Beng'},
#  {'name': 'Lange Vivian',
#   'alias': None,
#   'year_of_birth': 1997,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Female',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Lange Vivian'},
#  {'name': 'Lage Vivian',
#   'alias': None,
#   'year_of_birth': 1997,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Female',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Lange Vivian'},
#  {'name': 'Lage Vivien',
#   'alias': None,
#   'year_of_birth': 1997,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Female',
#   'nationality': 'Singapore',
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Lange Vivian'},
#  {'name': 'Laeg Vivian',
#   'alias': None,
#   'year_of_birth': 1997,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Female',
#   'nationality': 'Singapore',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Lange Vivian'},
#  {'name': 'Mas Selamat Kastari',
#   'alias': None,
#   'year_of_birth': 1961,
#   'month_of_birth': 1,
#   'day_of_birth': 23,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Mas Selamat Kastari'},
#  {'name': 'Mas Salamat Kestari',
#   'alias': None,
#   'year_of_birth': 1961,
#   'month_of_birth': 1,
#   'day_of_birth': 23,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Phonetic variations',
#   'actual_name': 'Mas Selamat Kastari'},
#  {'name': 'Selamat Mas Kastari',
#   'alias': None,
#   'year_of_birth': 1961,
#   'month_of_birth': 1,
#   'day_of_birth': 23,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'name order variation',
#   'actual_name': 'Mas Selamat Kastari'},
#  {'name': 'Msa Salemat Kastari',
#   'alias': None,
#   'year_of_birth': 1961,
#   'month_of_birth': 1,
#   'day_of_birth': 23,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Mas Selamat Kastari'},
#  {'name': 'Noordin Mohammad Top',
#   'alias': None,
#   'year_of_birth': 1968,
#   'month_of_birth': 8,
#   'day_of_birth': 11,
#   'gender': 'Male',
#   'nationality': 'Malaysia',
#   'type_of_error': '-',
#   'actual_name': 'Noordin Mohammad Top'},
#  {'name': 'Noordin Muhammad Top',
#   'alias': None,
#   'year_of_birth': 1968,
#   'month_of_birth': 8,
#   'day_of_birth': 11,
#   'gender': 'Male',
#   'nationality': 'Malaysia',
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Noordin Mohammad Top'},
#  {'name': 'Norodni Mohamamd Tpo',
#   'alias': None,
#   'year_of_birth': 1968,
#   'month_of_birth': 8,
#   'day_of_birth': 11,
#   'gender': 'Male',
#   'nationality': 'Malaysia',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Noordin Mohammad Top'},
#  {'name': 'Mohd Firdaus Kamal Intdzam',
#   'alias': None,
#   'year_of_birth': 1987,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Malaysia',
#   'type_of_error': '-',
#   'actual_name': 'Mohd Firdaus Kamal Intdzam'},
#  {'name': 'Mohd Kamal Firdaus Intdsam',
#   'alias': None,
#   'year_of_birth': 1987,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Malaysia',
#   'type_of_error': 'name order variation, Spelling/Phonetic',
#   'actual_name': 'Mohd Firdaus Kamal Intdzam'},
#  {'name': 'Mohammad Firdaus Kamal Intdzam',
#   'alias': None,
#   'year_of_birth': 1987,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Malaysia',
#   'type_of_error': 'Short/long form',
#   'actual_name': 'Mohd Firdaus Kamal Intdzam'},
#  {'name': 'Jens Fred Sturzenegger',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Sweden',
#   'type_of_error': '-',
#   'actual_name': 'Jens Fred Sturzenegger'},
#  {'name': 'Jan Sturzenegger',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Sweden',
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Jen Sturzenegger'},
#  {'name': 'Jen Sturzenegger',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Sweden',
#   'type_of_error': 'Short/long form',
#   'actual_name': 'Jen Sturzenegger'},
#  {'name': 'Bidzina Ivanishvili',
#   'alias': None,
#   'year_of_birth': 1956,
#   'month_of_birth': 2,
#   'day_of_birth': 18,
#   'gender': 'Male',
#   'nationality': 'Georgia',
#   'type_of_error': '-',
#   'actual_name': 'Bidzina Ivanishvili'},
#  {'name': 'Ivanishvili Bidzina',
#   'alias': None,
#   'year_of_birth': 1956,
#   'month_of_birth': 2,
#   'day_of_birth': 18,
#   'gender': 'Male',
#   'nationality': 'Georgia',
#   'type_of_error': 'name order variation',
#   'actual_name': 'Bidzina Ivanishvili'},
#  {'name': 'Bdizian Ianvishvlii',
#   'alias': None,
#   'year_of_birth': 1956,
#   'month_of_birth': 2,
#   'day_of_birth': 18,
#   'gender': 'Male',
#   'nationality': 'Georgia',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Bidzina Ivanishvili'},
#  {'name': 'Bedzina Ivenishvili',
#   'alias': None,
#   'year_of_birth': 1956,
#   'month_of_birth': 2,
#   'day_of_birth': 18,
#   'gender': 'Male',
#   'nationality': 'Georgia',
#   'type_of_error': 'Typo',
#   'actual_name': 'Bidzina Ivanishvili'},
#  {'name': 'Bernard Kan Cheok Yin',
#   'alias': 'jian zuo ying',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Bernard Kan Cheok Yin'},
#  {'name': 'Gan Cheok Yin',
#   'alias': 'jian zuo ying',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Transcription',
#   'actual_name': 'Bernard Kan Cheok Yin'},
#  {'name': 'Kan Cheok Yin Benard',
#   'alias': 'jian zuo ying',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'name order variation, Typo',
#   'actual_name': 'Bernard Kan Cheok Yin'},
#  {'name': 'Brenard Kan Choek Yin',
#   'alias': 'jian zuo ying',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Bernard Kan Cheok Yin'},
#  {'name': 'Bern Kan Cheok Yin',
#   'alias': 'jian zuo ying',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Short/long form',
#   'actual_name': 'Bernard Kan Cheok Yin'},
#  {'name': 'Ng Yu Zhi',
#   'alias': None,
#   'year_of_birth': 1987,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Ng Yu Zhi'},
#  {'name': 'Ng Yu Zhe',
#   'alias': None,
#   'year_of_birth': 1987,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Typo',
#   'actual_name': 'Ng Yu Zhi'},
#  {'name': 'Ng Yu Zih',
#   'alias': None,
#   'year_of_birth': 1987,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Ng Yu Zhi'},
#  {'name': 'LAI, Yong Chian',
#   'alias': 'Leonard LAI',
#   'year_of_birth': 1958,
#   'month_of_birth': 6,
#   'day_of_birth': 16,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'LAI, Yong Chian'},
#  {'name': 'LAI, Yong Qian',
#   'alias': 'Leonard LAI',
#   'year_of_birth': 1958,
#   'month_of_birth': 6,
#   'day_of_birth': 16,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Typo',
#   'actual_name': 'LAI, Yong Chian'},
#  {'name': 'chian lai yong',
#   'alias': None,
#   'year_of_birth': 1958,
#   'month_of_birth': 6,
#   'day_of_birth': 16,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'LAI, Yong Chian'},
#  {'name': 'Ahmed Faysal',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Bangladesh',
#   'type_of_error': '-',
#   'actual_name': 'Ahmed Faysal'},
#  {'name': 'Ahmed Faisar',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Bangladesh',
#   'type_of_error': 'Typo',
#   'actual_name': 'Ahmed Faysal'},
#  {'name': 'Ng Kheng Wah',
#   'alias': None,
#   'year_of_birth': 1962,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Ng Kheng Wah'},
#  {'name': 'Kheng Ng Wah',
#   'alias': None,
#   'year_of_birth': 1962,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Ng Kheng Wah'},
#  {'name': 'Ng King Wa',
#   'alias': None,
#   'year_of_birth': 1962,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Typo',
#   'actual_name': 'Ng Kheng Wah'},
#  {'name': 'Wang Zhiguo',
#   'alias': None,
#   'year_of_birth': 1963,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'China',
#   'type_of_error': '-',
#   'actual_name': 'Wang Zhiguo'},
#  {'name': 'Huang Zhiguo',
#   'alias': None,
#   'year_of_birth': 1963,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'China',
#   'type_of_error': 'Transcription',
#   'actual_name': 'Wang Zhiguo'},
#  {'name': 'Huaang Zhiguo',
#   'alias': None,
#   'year_of_birth': 1963,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'China',
#   'type_of_error': 'Phonetic variations',
#   'actual_name': 'Wang Zhiguo'},
#  {'name': 'Wnag Zihgou',
#   'alias': None,
#   'year_of_birth': 1963,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'China',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Wang Zhiguo'},
#  {'name': 'Tay Sheng Yang',
#   'alias': 'Allister Tay',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': '-',
#   'actual_name': 'Tay Sheng Yang'},
#  {'name': 'Sheng Yang Tay',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Tay Sheng Yang'},
#  {'name': 'Tay Shen Yan',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Typo',
#   'actual_name': 'Tay Sheng Yang'},
#  {'name': 'Tay Sehng Ynag',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Singapore',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Tay Sheng Yang'},
#  {'name': 'SAHIN Huseyin',
#   'alias': None,
#   'year_of_birth': 1957,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'SAHIN Huseyin'},
#  {'name': 'SAHI Huseying',
#   'alias': None,
#   'year_of_birth': 1957,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'SAHIN Huseyin'},
#  {'name': 'ABDUL AL MAJID',
#   'alias': None,
#   'year_of_birth': 1955,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': '-',
#   'actual_name': 'ABDUL AL MAJID'},
#  {'name': 'Abdulalmajid',
#   'alias': None,
#   'year_of_birth': 1955,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': 'Transcription',
#   'actual_name': 'ABDUL AL MAJID'},
#  {'name': 'ARDHAN, Muhamad Ricky',
#   'alias': 'SYAH, Heris',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': '-',
#   'actual_name': 'ARDHAN, Muhamad Ricky'},
#  {'name': 'ARDHAN, Mohd Ricky',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': 'Short/Long Form, Phonetic',
#   'actual_name': 'ARDHAN, Muhamad Ricky'},
#  {'name': 'UMANGIS MIKE',
#   'alias': 'JAFAR, Anis Alawi',
#   'year_of_birth': 1966,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': '-',
#   'actual_name': 'UMANGIS MIKE'},
#  {'name': 'UMANGIS MICHAEL',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': 'Short/Long Form',
#   'actual_name': 'UMANGIS MIKE'},
#  {'name': 'TORIQUDDIN',
#   'alias': 'RUSDAN, Abu',
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'TORIQUDDIN'},
#  {'name': 'SYAH, Heris',
#   'alias': 'ABDUL RAHMAN,\nMuhammad Jibril',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': '-',
#   'actual_name': 'SYAH, Heris'},
#  {'name': 'Muhammad Bahrun Naim Anggih',
#   'alias': 'AISYAH, Abu',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': '-',
#   'actual_name': 'Muhammad Bahrun Naim Anggih'},
#  {'name': 'Rachmat Yasin',
#   'alias': None,
#   'year_of_birth': 1963,
#   'month_of_birth': 11,
#   'day_of_birth': 4,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': '-',
#   'actual_name': 'Rachmat Yasin'},
#  {'name': 'YAZID SUFAAT',
#   'alias': 'Yazud bin Sufaat',
#   'year_of_birth': 1964,
#   'month_of_birth': 1,
#   'day_of_birth': 20,
#   'gender': 'Male',
#   'nationality': 'Malaysia',
#   'type_of_error': '-',
#   'actual_name': 'YAZID SUFAAT'},
#  {'name': 'MUHAMMAD AL-INDUNISI, Abu',
#   'alias': 'SYAH, Bahrum',
#   'year_of_birth': 1984,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': '-',
#   'actual_name': 'MUHAMMAD AL-INDUNISI, Abu'},
#  {'name': 'MUHAMMADALINDUNISI',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Indonesia',
#   'type_of_error': 'Short/Long Form, Phonetic',
#   'actual_name': 'MUHAMMAD AL-INDUNISI, Abu'},
#  {'name': 'PETER SONDAKH',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'PETER SONDAKH'},
#  {'name': 'PETER SONDAK',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'PETER SONDAKH'},
#  {'name': 'PETER SONJAK',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transcription',
#   'actual_name': 'PETER SONDAKH'},
#  {'name': 'GARIBALDI THOHIR',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'GARIBALDI THOHIR'},
#  {'name': 'GARIBADI THOHI',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'GARIBALDI THOHIR'},
#  {'name': 'Mikael Kambuaya',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Mikael Kambuaya'},
#  {'name': 'Michael Kambuaya',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transcription',
#   'actual_name': 'Mikael Kambuaya'},
#  {'name': 'Mike Kambuaya',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Short/Long Form',
#   'actual_name': 'Mikael Kambuaya'},
#  {'name': 'Pinangki Sirna Malasari',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Female',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Pinangki Sirna Malasari'},
#  {'name': 'Djoko Tjandra',
#   'alias': 'Tjan Kok Hui',
#   'year_of_birth': 1951,
#   'month_of_birth': 8,
#   'day_of_birth': 27,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Djoko Tjandra'},
#  {'name': 'Joko Tjandra',
#   'alias': None,
#   'year_of_birth': 1951,
#   'month_of_birth': 8,
#   'day_of_birth': 27,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transcription',
#   'actual_name': 'Djoko Tjandra'},
#  {'name': 'Djoko Tanjdar',
#   'alias': None,
#   'year_of_birth': 1951,
#   'month_of_birth': 8,
#   'day_of_birth': 27,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Djoko Tjandra'},
#  {'name': 'Tubagus Chaeri Wardana',
#   'alias': 'Wawan',
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Tubagus Chaeri Wardana'},
#  {'name': 'Budi Santoso',
#   'alias': None,
#   'year_of_birth': 1948,
#   'month_of_birth': 2,
#   'day_of_birth': 28,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Budi Santoso'},
#  {'name': 'Budy Santoso',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transcription',
#   'actual_name': 'Budi Santoso'},
#  {'name': 'Irzal Rinaldi Zailani',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Irzal Rinaldi Zailani'},
#  {'name': 'Irsal Rinaldi Sailani',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Phonetic variations',
#   'actual_name': 'Irzal Rinaldi Zailani'},
#  {'name': 'Risyanto Suanda',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Risyanto Suanda'},
#  {'name': 'Risayanto Suanda',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Risyanto Suanda'},
#  {'name': 'Rizyanto Suanda',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Phonetic variations',
#   'actual_name': 'Risyanto Suanda'},
#  {'name': 'Muhammad Romahurmuziy',
#   'alias': 'Romy',
#   'year_of_birth': 1974,
#   'month_of_birth': 9,
#   'day_of_birth': 10,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Muhammad Romahurmuziy'},
#  {'name': 'Mohamed Romy',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Short/Long Form',
#   'actual_name': 'Muhammad Romahurmuziy'},
#  {'name': 'SABRINA ABU',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'SABRINA ABU'},
#  {'name': 'SHABRINA, Abu',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Phonetic variations',
#   'actual_name': 'SABRINA ABU'},
#  {'name': 'ABDUL TAIB MAHMUD',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'ABDUL TAIB MAHMUD'},
#  {'name': 'ABDUL TIAB MAHMUD',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'ABDUL TAIB MAHMUD'},
#  {'name': 'Prasetyo Utomo',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Prasetyo Utomo'},
#  {'name': 'Utomo Prasetyo',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Prasetyo Utomo'},
#  {'name': 'Rodrigo Roa Duterte',
#   'alias': None,
#   'year_of_birth': 1945,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Philippines',
#   'type_of_error': '-',
#   'actual_name': 'Rodrigo Roa Duterte'},
#  {'name': 'Duterte Roa Rodrigo',
#   'alias': None,
#   'year_of_birth': 1945,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Philippines',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Rodrigo Roa Duterte'},
#  {'name': 'Rodrigo Roa',
#   'alias': None,
#   'year_of_birth': 1945,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Philippines',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Rodrigo Roa Duterte'},
#  {'name': 'Rodrygo Duterte Roa',
#   'alias': None,
#   'year_of_birth': 1945,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Philippines',
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Rodrigo Roa Duterte'},
#  {'name': 'Rodrgio Duteert Rao',
#   'alias': None,
#   'year_of_birth': 1945,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Philippines',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Rodrigo Roa Duterte'},
#  {'name': 'Rodrigol Roaa Dutertee',
#   'alias': None,
#   'year_of_birth': 1945,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': 'Philippines',
#   'type_of_error': 'Typo',
#   'actual_name': 'Rodrigo Roa Duterte'},
#  {'name': 'Amin Imam Boratong',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Amin Imam Boratong'},
#  {'name': 'Amin Boratong',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Amin Imam Boratong'},
#  {'name': 'Amin Boratong Imam',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Amin Imam Boratong'},
#  {'name': 'Amin Boratngo Imam',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Amin Imam Boratong'},
#  {'name': 'Ami Imam Boratong',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Amin Imam Boratong'},
#  {'name': 'Ameen Imam Boratong',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Amin Imam Boratong'},
#  {'name': 'Roberto Salas Benedicto',
#   'alias': None,
#   'year_of_birth': 1917,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Roberto Salas Benedicto'},
#  {'name': 'Roberto Benedicto Salas',
#   'alias': None,
#   'year_of_birth': 1917,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Roberto Salas Benedicto'},
#  {'name': 'Roberot Salas Benedict',
#   'alias': None,
#   'year_of_birth': 1917,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Roberto Salas Benedicto'},
#  {'name': 'Robert Benedict Salas',
#   'alias': None,
#   'year_of_birth': 1917,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Roberto Salas Benedicto'},
#  {'name': 'Bob Benedict Salas',
#   'alias': None,
#   'year_of_birth': 1917,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Short/Long Form',
#   'actual_name': 'Roberto Salas Benedicto'},
#  {'name': 'Jose Calida',
#   'alias': None,
#   'year_of_birth': 1950,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Jose Calida'},
#  {'name': 'José Calida',
#   'alias': None,
#   'year_of_birth': 1950,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Diacritical mark/accent variations',
#   'actual_name': 'Jose Calida'},
#  {'name': 'Calida Jose',
#   'alias': None,
#   'year_of_birth': 1950,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Jose Calida'},
#  {'name': 'Jose Cailda',
#   'alias': None,
#   'year_of_birth': 1950,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Jose Calida'},
#  {'name': 'Jos Calida',
#   'alias': None,
#   'year_of_birth': 1950,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Jose Calida'},
#  {'name': 'Hose Calida',
#   'alias': None,
#   'year_of_birth': 1950,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Jose Calida'},
#  {'name': 'Antonio Floirendo, Sr.',
#   'alias': None,
#   'year_of_birth': 1915,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Antonio Floirendo, Sr.'},
#  {'name': 'Antonio Sr. Floirendo',
#   'alias': None,
#   'year_of_birth': 1915,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Antonio Floirendo, Sr.'},
#  {'name': 'Antiiono Sr. Floirendo',
#   'alias': None,
#   'year_of_birth': 1915,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Antonio Floirendo, Sr.'},
#  {'name': 'Antoni Floirendo, Sr.',
#   'alias': None,
#   'year_of_birth': 1915,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Antonio Floirendo, Sr.'},
#  {'name': 'Antonio Floirendo, Senior',
#   'alias': None,
#   'year_of_birth': 1915,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Short/Long Form',
#   'actual_name': 'Antonio Floirendo, Sr.'},
#  {'name': 'Erwin Tulfo',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Erwin Tulfo'},
#  {'name': 'Tulfo Erwin',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Erwin Tulfo'},
#  {'name': 'Eriwn Tulof',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Erwin Tulfo'},
#  {'name': 'Erwin Turlfur',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Erwin Tulfo'},
#  {'name': 'Erwin Tulpho',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Erwin Tulfo'},
#  {'name': 'Lucio Tan',
#   'alias': None,
#   'year_of_birth': 1934,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Lucio Tan'},
#  {'name': 'Tan Lucio',
#   'alias': None,
#   'year_of_birth': 1934,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Lucio Tan'},
#  {'name': 'Lucoi Tan',
#   'alias': None,
#   'year_of_birth': 1934,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Lucio Tan'},
#  {'name': 'Lucioooo Tam',
#   'alias': None,
#   'year_of_birth': 1934,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Lucio Tan'},
#  {'name': 'Lucius Tan',
#   'alias': None,
#   'year_of_birth': 1934,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Short/Long Form',
#   'actual_name': 'Lucio Tan'},
#  {'name': 'Hung Kin Sing Jimmy',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Hung Kin Sing Jimmy'},
#  {'name': 'Hung Jimmy',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Hung Kin Sing Jimmy'},
#  {'name': 'Jimmy Hung Kin Sing',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Hung Kin Sing Jimmy'},
#  {'name': 'Jimmy Kin Hung Sing',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Hung Kin Sing Jimmy'},
#  {'name': 'Hnug Kni Sing Jimmy',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Hung Kin Sing Jimmy'},
#  {'name': 'Hungg Kin Sim Jimmy',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Hung Kin Sing Jimmy'},
#  {'name': 'Hung Kin Sing Jim',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Short/Long Form',
#   'actual_name': 'Hung Kin Sing Jimmy'},
#  {'name': 'Hung Kin Sing James',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Short/Long Form',
#   'actual_name': 'Hung Kin Sing Jimmy'},
#  {'name': 'Alan Purisima',
#   'alias': None,
#   'year_of_birth': 1959,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Alan Purisima'},
#  {'name': 'Purisima Alan',
#   'alias': None,
#   'year_of_birth': 1959,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Alan Purisima'},
#  {'name': 'Aaln Purisima',
#   'alias': None,
#   'year_of_birth': 1959,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Alan Purisima'},
#  {'name': 'Aln Purisma',
#   'alias': None,
#   'year_of_birth': 1959,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Alan Purisima'},
#  {'name': 'Alan Burisima',
#   'alias': None,
#   'year_of_birth': 1959,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': 'Male',
#   'nationality': None,
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Alan Purisima'},
#  {'name': 'Chang Chang Ha',
#   'alias': None,
#   'year_of_birth': 1964,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Chang Chang Ha'},
#  {'name': 'Chang Ha Chang',
#   'alias': None,
#   'year_of_birth': 1964,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Chang Chang Ha'},
#  {'name': 'Chnga Cghna Ah',
#   'alias': None,
#   'year_of_birth': 1964,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Chang Chang Ha'},
#  {'name': 'Chang Chang Haaaaaa',
#   'alias': None,
#   'year_of_birth': 1964,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Chang Chang Ha'},
#  {'name': 'Jang Jang Ha',
#   'alias': None,
#   'year_of_birth': 1964,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Transcription',
#   'actual_name': 'Chang Chang Ha'},
#  {'name': 'Kim Song Chol',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': '-',
#   'actual_name': 'Kim Song Chol'},
#  {'name': 'Kim Chol Song',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Kim Song Chol'},
#  {'name': 'Kmi Snog Chol',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Kim Song Chol'},
#  {'name': 'Kimm Chol Songg',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Typo',
#   'actual_name': 'Kim Song Chol'},
#  {'name': 'Kim Sung Cheol',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Transcription',
#   'actual_name': 'Kim Song Chol'},
#  {'name': 'Kim Seong Chol',
#   'alias': None,
#   'year_of_birth': None,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': None,
#   'nationality': 'North Korea',
#   'type_of_error': 'Transcription',
#   'actual_name': 'Kim Song Chol'},
#  {'name': 'Cho Chun Ryong',
#   'alias': 'Jo, Chun Ryong',
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Cho Chun Ryong'},
#  {'name': 'Cho Ryong Chun',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Cho Chun Ryong'},
#  {'name': 'Coh Royng Chun',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Cho Chun Ryong'},
#  {'name': 'Choo Chung Ryoung',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Cho Chun Ryong'},
#  {'name': 'Jo Jun Yong',
#   'alias': None,
#   'year_of_birth': 1960,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Transcription',
#   'actual_name': 'Cho Chun Ryong'},
#  {'name': 'Pak Chun il',
#   'alias': None,
#   'year_of_birth': 1954,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': '-',
#   'actual_name': 'Pak Chun il'},
#  {'name': 'Pak il Chun',
#   'alias': None,
#   'year_of_birth': 1954,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Pak Chun il'},
#  {'name': 'Pak chun li',
#   'alias': None,
#   'year_of_birth': 1954,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Pak Chun il'},
#  {'name': 'Pa Chun il',
#   'alias': None,
#   'year_of_birth': 1954,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Typo',
#   'actual_name': 'Pak Chun il'},
#  {'name': 'Park Chun il',
#   'alias': None,
#   'year_of_birth': 1954,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Spelling/Phonetic',
#   'actual_name': 'Pak Chun il'},
#  {'name': 'Jo Yong Chol',
#   'alias': 'Cho, Yong Chol',
#   'year_of_birth': 1973,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': '-',
#   'actual_name': 'Jo Yong Chol'},
#  {'name': 'Jo Chol Yong',
#   'alias': None,
#   'year_of_birth': 1973,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Jo Yong Chol'},
#  {'name': 'Jo Ynog Chlo',
#   'alias': None,
#   'year_of_birth': 1973,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Jo Yong Chol'},
#  {'name': 'Joh Yong Chol',
#   'alias': None,
#   'year_of_birth': 1973,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Typo',
#   'actual_name': 'Jo Yong Chol'},
#  {'name': 'Cho Yong Chol',
#   'alias': None,
#   'year_of_birth': 1973,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Transcription',
#   'actual_name': 'Jo Yong Chol'},
#  {'name': 'Son Jong Hyok',
#   'alias': 'Son, Min',
#   'year_of_birth': 1980,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': '-',
#   'actual_name': 'Son Jong Hyok'},
#  {'name': 'SON JONG KYOK',
#   'alias': None,
#   'year_of_birth': 1980,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Typo',
#   'actual_name': 'Son Jong Hyok'},
#  {'name': 'Son Hyok Jong',
#   'alias': None,
#   'year_of_birth': 1980,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Son Jong Hyok'},
#  {'name': 'Son Jong Hoyk',
#   'alias': None,
#   'year_of_birth': 1980,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Son Jong Hyok'},
#  {'name': 'So Jon Hyok',
#   'alias': None,
#   'year_of_birth': 1980,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Typo',
#   'actual_name': 'Son Jong Hyok'},
#  {'name': 'Son Jung Hyok',
#   'alias': None,
#   'year_of_birth': 1980,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': 'North Korea',
#   'type_of_error': 'Transcription',
#   'actual_name': 'Son Jong Hyok'},
#  {'name': 'Son Chung Hyeok',
#   'alias': None,
#   'year_of_birth': 1980,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': None,
#   'nationality': 'North Korea',
#   'type_of_error': 'Transcription',
#   'actual_name': 'Son Jong Hyok'},
#  {'name': 'Son Mun San',
#   'alias': None,
#   'year_of_birth': 1951,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': '-',
#   'actual_name': 'Son Mun San'},
#  {'name': 'Son San Mun',
#   'alias': None,
#   'year_of_birth': 1951,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Name order variation',
#   'actual_name': 'Son Mun San'},
#  {'name': 'Son Mnu San',
#   'alias': None,
#   'year_of_birth': 1951,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Transposed characters',
#   'actual_name': 'Son Mun San'},
#  {'name': 'So Mun San',
#   'alias': None,
#   'year_of_birth': 1951,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Typo',
#   'actual_name': 'Son Mun San'},
#  {'name': 'Son Moon San',
#   'alias': None,
#   'year_of_birth': 1951,
#   'month_of_birth': None,
#   'day_of_birth': None,
#   'gender': '-',
#   'nationality': None,
#   'type_of_error': 'Transcription',
#   'actual_name': 'Son Mun San'}]

# %% [markdown]
# ## Generate 5 articles for each name in the dataframe, getting rid of duplicates

# %%
details_dictionary = [] #stores the dictionary of the person we will use for confidence checking
names_searched = []
queries = [] 
for item in df_dict:
    if item['actual_name'] in names_searched:
        print(f"not searching {item['actual_name']} because already searched")
        continue
    else:
        queries.append(search_articles_on_individual(item, 5))
        names_searched.append(item['actual_name'])
        details_dictionary.append(item)
# Out:
# SEARCHING THIS https://www.google.com/search?q=Chia+Teck+Leng+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Chia+Teck+Leng+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Chia Teck Leng because already searched
# not searching Chia Teck Leng because already searched
# SEARCHING THIS https://www.google.com/search?q=Teo+Cheng+Kiat+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Teo+Cheng+Kiat+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Teo Cheng Kiat because already searched
# not searching Teo Cheng Kiat because already searched
# not searching Teo Cheng Kiat because already searched
# SEARCHING THIS https://www.google.com/search?q=Chong+Hock+Yen+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Chong+Hock+Yen+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Chong Hock Yen because already searched
# not searching Chong Hock Yen because already searched
# SEARCHING THIS https://www.google.com/search?q=Lim+Oon+Kuin+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Lim+Oon+Kuin+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Lim Oon Kuin because already searched
# not searching Lim Oon Kuin because already searched
# SEARCHING THIS https://www.google.com/search?q=Tan+Wee+Beng+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Tan+Wee+Beng+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Tan Wee Beng because already searched
# SEARCHING THIS https://www.google.com/search?q=Lange+Vivian+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Lange+Vivian+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Lange Vivian because already searched
# not searching Lange Vivian because already searched
# not searching Lange Vivian because already searched
# SEARCHING THIS https://www.google.com/search?q=Mas+Selamat+Kastari+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=
identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# SEARCHING THIS https://www.google.com/search?q=Muhammad+Bahrun+Naim+Anggih+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Rachmat+Yasin+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Rachmat+Yasin+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=YAZID+SUFAAT+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=YAZID+SUFAAT+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=MUHAMMAD+AL-INDUNISI,+Abu+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=MUHAMMAD+AL-INDUNISI,+Abu+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching MUHAMMAD AL-INDUNISI, Abu because already searched
# SEARCHING THIS https://www.google.com/search?q=PETER+SONDAKH+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=PETER+SONDAKH+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching PETER SONDAKH because already searched
# not searching PETER SONDAKH because already searched
# SEARCHING THIS https://www.google.com/search?q=GARIBALDI+THOHIR+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=GARIBALDI+THOHIR+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching GARIBALDI THOHIR because already searched
# SEARCHING THIS https://www.google.com/search?q=Mikael+Kambuaya+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Mikael+Kambuaya+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Mikael Kambuaya because already searched
# not searching Mikael Kambuaya because already searched
# SEARCHING THIS https://www.google.com/search?q=Pinangki+Sirna+Malasari+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Pinangki+Sirna+Malasari+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Djoko+Tjandra+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Djoko+Tjandra+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Djoko Tjandra because already searched
# not searching Djoko Tjandra because already searched
# SEARCHING THIS https://www.google.com/search?q=Tubagus+Chaeri+Wardana+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Tubagus+Chaeri+Wardana+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Budi+Santoso+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Budi+Santoso+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Budi Santoso because already searched
# SEARCHING THIS https://www.google.com/search?q=Irzal+Rinaldi+Zailani+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Irzal+Rinaldi+Zailani+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Irzal Rinaldi Zailani because already searched
# SEARCHING THIS https://www.google.com/search?q=Risyanto+Suanda+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Risyanto+Suanda+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Risyanto Suanda because already searched
# not searching Risyanto Suanda because already searched
# SEARCHING THIS https://www.google.com/search?q=Muhammad+Romahurmuziy+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Muhammad+Romahurmuziy+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Muhammad Romahurmuziy because already searched
# SEARCHING THIS https://www.google.com/search?q=SABRINA+ABU+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=SABRINA+ABU+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching SABRINA ABU because already searched
# SEARCHING THIS https://www.google.com/search?q=ABDUL+TAIB+MAHMUD+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=ABDUL+TAIB+MAHMUD+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching ABDUL TAIB MAHMUD because already searched
# SEARCHING THIS https://www.google.com/search?q=Prasetyo+Utomo+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Prasetyo+Utomo+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Prasetyo Utomo because already searched
# SEARCHING THIS https://www.google.com/search?q=Rodrigo+Roa+Duterte+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Rodrigo+Roa+Duterte+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Rodrigo Roa Duterte because already searched
# not searching Rodrigo Roa Duterte because already searched
# not searching Rodrigo Roa Duterte because already searched
# not searching Rodrigo Roa Duterte because already searched
# not searching Rodrigo Roa Duterte because already searched
# SEARCHING THIS https://www.google.com/search?q=Amin+Imam+Boratong+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Amin+Imam+Boratong+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# C:\Users\USER\Anaconda\lib\site-packages\dateutil\parser\_parser.py:1213: UnknownTimezoneWarning: tzname PST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# not searching Amin Imam Boratong because already searched
# not searching Amin Imam Boratong because already searched
# not searching Amin Imam Boratong because already searched
# not searching Amin Imam Boratong because already searched
# not searching Amin Imam Boratong because already searched
# SEARCHING THIS https://www.google.com/search?q=Roberto+Salas+Benedicto+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Roberto+Salas+Benedicto+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Roberto Salas Benedicto because already searched
# not searching Roberto Salas Benedicto because already searched
# not searching Roberto Salas Benedicto because already searched
# not searching Roberto Salas Benedicto because already searched
# SEARCHING THIS https://www.google.com/search?q=Jose+Calida+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Jose+Calida+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Jose Calida because already searched
# not searching Jose Calida because already searched
# not searching Jose Calida because already searched
# not searching Jose Calida because already searched
# not searching Jose Calida because already searched
# SEARCHING THIS https://www.google.com/search?q=Antonio+Floirendo,+Sr.+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Antonio+Floirendo,+Sr.+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Antonio Floirendo, Sr. because already searched
# not searching Antonio Floirendo, Sr. because already searched
# not searching Antonio Floirendo, Sr. because already searched
# not searching Antonio Floirendo, Sr. because already searched
# SEARCHING THIS https://www.google.com/search?q=Erwin+Tulfo+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Erwin+Tulfo+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Erwin Tulfo because already searched
# not searching Erwin Tulfo because already searched
# not searching Erwin Tulfo because already searched
# not searching Erwin Tulfo because already searched
# SEARCHING THIS https://www.google.com/search?q=Lucio+Tan+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Lucio+Tan+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Lucio Tan because already searched
# not searching Lucio Tan because already searched
# not searching Lucio Tan because already searched
# not searching Lucio Tan because already searched
# SEARCHING THIS https://www.google.com/search?q=Hung+Kin+Sing+Jimmy+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Hung+Kin+Sing+Jimmy+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Hung Kin Sing Jimmy because already searched
# not searching Hung Kin Sing Jimmy because already searched
# not searching Hung Kin Sing Jimmy because already searched
# not searching Hung Kin Sing Jimmy because already searched
# not searching Hung Kin Sing Jimmy because already searched
# not searching Hung Kin Sing Jimmy because already searched
# not searching Hung Kin Sing Jimmy because already searched
# SEARCHING THIS https://www.google.com/search?q=Alan+Purisima+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Alan+Purisima+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Alan Purisima because already searched
# not searching Alan Purisima because already searched
# not searching Alan Purisima because already searched
# not searching Alan Purisima because already searched
# SEARCHING THIS https://www.google.com/search?q=Chang+Chang+Ha+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Chang+Chang+Ha+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Chang Chang Ha because already searched
# not searching Chang Chang Ha because already searched
# not searching Chang Chang Ha because already searched
# not searching Chang Chang Ha because already searched
# SEARCHING THIS https://www.google.com/search?q=Kim+Song+Chol+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Kim+Song+Chol+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Kim Song Chol because already searched
# not searching Kim Song Chol because already searched
# not searching Kim Song Chol because already searched
# not searching Kim Song Chol because already searched
# not searching Kim Song Chol because already searched
# SEARCHING THIS https://www.google.com/search?q=Cho+Chun+Ryong+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Cho+Chun+Ryong+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Cho Chun Ryong because already searched
# not searching Cho Chun Ryong because already searched
# not searching Cho Chun Ryong because already searched
# not searching Cho Chun Ryong because already searched
# SEARCHING THIS https://www.google.com/search?q=Pak+Chun+il+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Pak+Chun+il+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Pak Chun il because already searched
# not searching Pak Chun il because already searched
# not searching Pak Chun il because already searched
# not searching Pak Chun il because already searched
# SEARCHING THIS https://www.google.com/search?q=Jo+Yong+Chol+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Jo+Yong+Chol+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching Jo Yong Chol because already searched
# not searching Jo Yong Chol because already searched
# not searching Jo Yong Chol because already searched
# not searching Jo Yong Chol because already searched
# SEARCHING THIS https://www.google.com/search?q=Son+Jong+Hyok+crimes&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# SEARCHING THIS https://www.google.com/search?q=Son+Jong+Hyok+sentenced&sxsrf=ALeKk01K1bOuJFHjy4HBARo1cRpUYakYPg:1629640327633&source=lnms&tbm=nws&sa=X&sqi=2&ved=2ahUKEwiu29um48TyAhWGqpUCHYuoAlcQ_AUoAnoECAEQBA&biw=1441&bih=718&dpr=2&num=5
# not searching
ing behind its back. Chia remained in sole control of all these accounts by forging director board resolutions that authorised him to receive the credit and loan facilities provided, sign all transactions and operate the bank accounts on behalf of APB.\n\nTo forge the signatures of the various directors of APB, he obtained specimens from annual reports and internal documents. He practised the signatures till he was sure they would pass muster.\n\nChia’s modus operandi was to draw money from SMBC, Mizuho and HVB, and transfer it to the SEB account. From there, the money was siphoned into his two personal accounts with DBS before it was remitted to casinos in Australia, Britain, Hong Kong, Malaysia and the Philippines.\n\nHe rolled over funds provided by the banks, making timely deposits to each account whenever repayments were due, thus creating the impression of a credit-worthy customer.\n\nDuring a crunch situation in November 1999, he even withdrew $53 million from an AP ...
#  'sentiment?': {'neg': 0.453, 'neu': 0.495, 'pos': 0.052, 'compound': -1.0},
#  'names_list': Counter({'Chia Teck Leng': 4,
#           'Chia': 10,
#           'Tay Yong Kwang': 1,
#           'Tay': 1,
#           'Li Jin': 2,
#           'Li': 2,
#           'Arthur Andersen': 1,
#           'Chu Chiao-Ling': 1,
#           'Skandinaviska Enskilda Banken': 1,
#           'Belinda Ang': 1,
#           'Guilty': 1})}

# %%
#for each item in queries, make them into dataframe and append each other together


#def entity_recognition_scoring(input_info, list_of_article_dicts):
dataframes = []



for i in range(1,len(queries)):
    details = details_dictionary[i]
    query = queries[i]
    
    temp_df = pd.DataFrame(entity_recognition_scoring(details, query))
    dataframes.append(temp_df)

#main_test_df

# %%
main_test_df = pd.DataFrame(entity_recognition_scoring(details_dictionary[0], queries[0]))

# %%
for item in dataframes:
    main_test_df = main_test_df.append(item)
    
main_test_df
# Out:
#                                                 title           time  \
# 0   Guilty As Charged: Chia Teck Leng led a double...  64 months ago
# 1   Guilty As Charged: Chia Teck Leng led a double...  64 months ago
# 2   Guilty As Charged: Chia Teck Leng led a double...  64 months ago
# 3   Accountant who embezzled $40m a compulsive gam...  28 months ago
# 4   Accountant who embezzled $40m a compulsive gam...  28 months ago
# ..                                                ...            ...
# 10  Former South Korean president sentenced to prison  10 months ago
# 11  Former South Korean president sentenced to prison  10 months ago
# 0   Asian American Elders Stand Resilient in the W...   2 months ago
# 1   Asian American Elders Stand Resilient in the W...   2 months ago
# 2   Asian American Elders Stand Resilient in the W...   2 months ago
#
#     year_of_birth                                        description  \
# 0              56  Asia Pacific Breweries executive Chia Teck Len...
# 1              56  Asia Pacific Breweries executive Chia Teck Len...
# 2              56  Asia Pacific Breweries executive Chia Teck Len...
# 3              59  While Ewe did not amass riches from his crimes...
# 4              59  While Ewe did not amass riches from his crimes...
# ..            ...                                                ...
# 10             47  The 89-year-old former president called Cho Ch...
# 11             47  The 89-year-old former president called Cho Ch...
# 0              70  Growing up in San Francisco, Victoria Eng, 28,...
# 1              70  Growing up in San Francisco, Victoria Eng, 28,...
# 2              70  Growing up in San Francisco, Victoria Eng, 28,...
#
#                                                  link  \
# 0   https://www.straitstimes.com/singapore/courts-...
# 1   https://www.straitstimes.com/singapore/courts-...
# 2   https://www.straitstimes.com/singapore/courts-...
# 3   https://www.straitstimes.com/singapore/courts-...
# 4   https://www.straitstimes.com/singapore/courts-...
# ..                                                ...
# 10  https://www.dw.com/en/former-south-korean-pres...
# 11  https://www.dw.com/en/former-south-korean-pres...
# 0   https://time.com/6082120/asian-american-elders...
# 1   https://time.com/6082120/asian-american-elders...
# 2   https://time.com/6082120/asian-american-elders...
#
#                                                  text  \
# 0   This story was first published in July 2015 in...
# 1   This story was first published in July 2015 in...
# 2   This story was first published in July 2015 in...
# 3   SINGAPORE - Certified public accountant Ewe Pa...
# 4   SINGAPORE - Certified public accountant Ewe Pa...
# ..                                                ...
# 10  Former South Korean president Chun Doo-hwan wa...
# 11  Former South Korean president Chun Doo-hwan wa...
# 0   As the daughter of immigrants from China, grow...
# 1   As the daughter of immigrants from China, grow...
# 2   As the daughter of immigrants from China, grow...
#
#                                            sentiment?  \
# 0   {'neg': 0.453, 'neu': 0.495, 'pos': 0.052, 'co...
# 1   {'neg': 0.453, 'neu': 0.495, 'pos': 0.052, 'co...
# 2   {'neg': 0.453, 'neu': 0.495, 'pos': 0.052, 'co...
# 3   {'neg': 0.322, 'neu': 0.648, 'pos': 0.03, 'com...
# 4   {'neg': 0.322, 'neu': 0.648, 'pos': 0.03, 'com...
# ..                                                ...
# 10  {'neg': 0.661, 'neu': 0.303, 'pos': 0.036, 'co...
# 11  {'neg': 0.661, 'neu': 0.303, 'pos': 0.036, 'co...
# 0   {'neg': 0.179, 'neu': 0.741, 'pos': 0.079, 'co...
# 1   {'neg': 0.179, 'neu': 0.741, 'pos': 0.079, 'co...
# 2   {'neg': 0.179, 'neu': 0.741, 'pos': 0.079, 'co...
#
#                                            names_list  name_matching_score  \
# 0   {'Chia Teck Leng': 4, 'Chia': 10, 'Tay Yong Kw...                  100
# 1   {'Chia Teck Leng': 4, 'Chia': 10, 'Tay Yong Kw...                  100
# 2   {'Chia Teck Leng': 4, 'Chia': 10, 'Tay Yong Kw...                  100
# 3   {'Chia Teck Leng': 2, 'Ewe Pang Kooi': 1, 'Ewe...                  100
# 4   {'Chia Teck Leng': 2, 'Ewe Pang Kooi': 1, 'Ewe...                  100
# ..                                                ...                  ...
# 10  {'Cho Chul-hyun': 3, 'Kim Young-sam': 2, 'Chun...                  100
# 11  {'Cho Chul-hyun': 3, 'Kim Young-sam': 2, 'Chun...                  100
# 0   {'Victoria Eng': 2, 'Elizabeth': 6, 'Donald Tr...                  100
# 1   {'Victoria Eng': 2, 'Elizabeth': 6, 'Donald Tr...                  100
# 2   {'Victoria Eng': 2, 'Elizabeth': 6, 'Donald Tr...                  100
#
#     nationality_matching_score  gender_matching_score  age_matching_score
# 0                          1.0               0.901961                   0
# 1                          1.0               0.901961                   0
# 2                          1.0               0.901961                   0
# 3                          1.0               0.000000                   0
# 4                          1.0               0.000000                   0
# ..                         ...                    ...                 ...
# 10                        -1.0               0.000000                   0
# 11                        -1.0               0.000000                   0
# 0                          0.0               0.166667                   1
# 1                          0.0               0.166667                   1
# 2                          0.0               0.166667                   1
#
# [732 rows x 12 columns]

# %%
# only unique links in df
test = main_test_df.drop_duplicates(subset=['link'])

# %%
test.to_excel('test_data.xlsx')
